# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer = Tokenizer()

# %%
faqs = """

 What is Machine Learning?
   Machine Learning is a subset of artificial intelligence that focuses on the development of algorithms and models that allow computers to learn and make predictions or decisions without being explicitly programmed.
 What are the three main types of machine learning?
   The three main types of machine learning are supervised learning, unsupervised learning, and reinforcement learning.
 What is supervised learning?
   Supervised learning is a type of machine learning where the model is trained on a labeled dataset, meaning that it learns from input-output pairs. It learns to make predictions based on input data.
 What is unsupervised learning?
   Unsupervised learning is a type of machine learning where the model is given unlabeled data and must discover patterns and relationships on its own.
 What is reinforcement learning?
   Reinforcement learning is a type of machine learning where an agent learns to make a sequence of decisions by interacting with an environment. It receives rewards or penalties for its actions.
 What is the difference between classification and regression in machine learning?
   Classification is used when the output variable is a category or label, while regression is used when the output variable is a continuous value.
 What is overfitting in machine learning?
   Overfitting occurs when a model learns the training data too well, to the point that it starts to memorize noise or random fluctuations. This leads to poor performance on unseen data.
 How can overfitting be prevented?
   Overfitting can be prevented by using techniques like cross-validation, regularization, and collecting more diverse training data.
 What is the bias-variance tradeoff?
   The bias-variance tradeoff is the balance between a model's ability to fit the training data closely (low bias) and its ability to generalize to unseen data (low variance).
 What is a decision tree in machine learning?
    A decision tree is a supervised learning algorithm that makes decisions by asking a series of questions about the features of the data. It splits the data into branches based on these questions, ultimately leading to a prediction.
 What is the curse of dimensionality in machine learning?
    The curse of dimensionality refers to the challenges and difficulties that arise when working with high-dimensional data, where the number of features or dimensions is very large. It can lead to increased computational complexity and a need for larger amounts of data.
 What is feature engineering in machine learning?
    Feature engineering is the process of selecting, transforming, or creating new features from the existing data to improve the performance of a machine learning model.
 What is a neural network?
    A neural network is a type of machine learning model inspired by the structure and functioning of the human brain. It consists of interconnected nodes (neurons) organized in layers, and it's used for tasks like classification, regression, and pattern recognition.
 What is a convolutional neural network (CNN)?
    A convolutional neural network (CNN) is a specific type of neural network designed for processing grid-like data, such as images. It uses layers of convolution operations to automatically and adaptively learn features from the data.
 What is the purpose of batch normalization in deep learning?
    Batch normalization is a technique used in deep learning to improve the training process and stability of neural networks. It normalizes the inputs to a layer, helping to reduce internal covariate shifts and accelerate convergence.
 What is transfer learning in machine learning?
    Transfer learning is a technique where a pre-trained model, originally trained on a large dataset for a specific task, is fine-tuned or adapted for a different but related task with a smaller dataset.
 What is an ensemble method in machine learning?
    An ensemble method combines multiple machine learning models to improve overall performance. Common techniques include bagging (e.g., Random Forest), boosting (e.g., AdaBoost), and stacking.
 What is natural language processing (NLP) in machine learning?
    Natural Language Processing (NLP) is a field of machine learning focused on the interaction between computers and human language. It involves tasks like language translation, sentiment analysis, and text generation.
 What is the difference between precision and recall in classification?
    Precision is the ratio of true positives to the sum of true positives and false positives, while recall is the ratio of true positives to the sum of true positives and false negatives. Precision emphasizes the accuracy of positive predictions, while recall focuses on finding all positive instances.
 What is deep reinforcement learning?
    Deep reinforcement learning combines deep learning techniques with reinforcement learning principles. It involves training neural networks to make decisions based on a reward system, often used in complex tasks like playing video games or controlling autonomous systems.
"""

# %%
tokenizer.fit_on_texts([faqs])

# %%
 tokenizer.word_index
# Out:
# {'is': 1,
#  'learning': 2,
#  'the': 3,
#  'a': 4,
#  'of': 5,
#  'and': 6,
#  'to': 7,
#  'what': 8,
#  'machine': 9,
#  'data': 10,
#  'in': 11,
#  'it': 12,
#  'on': 13,
#  'or': 14,
#  'neural': 15,
#  'that': 16,
#  'reinforcement': 17,
#  'model': 18,
#  'for': 19,
#  'type': 20,
#  'where': 21,
#  'used': 22,
#  'training': 23,
#  'like': 24,
#  'network': 25,
#  'deep': 26,
#  'positives': 27,
#  'make': 28,
#  'decisions': 29,
#  'supervised': 30,
#  'learns': 31,
#  'an': 32,
#  'by': 33,
#  'with': 34,
#  'between': 35,
#  'classification': 36,
#  'when': 37,
#  'overfitting': 38,
#  'features': 39,
#  'language': 40,
#  'true': 41,
#  'predictions': 42,
#  'unsupervised': 43,
#  'trained': 44,
#  'dataset': 45,
#  'from': 46,
#  'output': 47,
#  'based': 48,
#  'its': 49,
#  'regression': 50,
#  'while': 51,
#  'performance': 52,
#  'can': 53,
#  'techniques': 54,
#  'bias': 55,
#  'variance': 56,
#  'improve': 57,
#  'tasks': 58,
#  'processing': 59,
#  'precision': 60,
#  'recall': 61,
#  'focuses': 62,
#  'models': 63,
#  'computers': 64,
#  'learn': 65,
#  'are': 66,
#  'three': 67,
#  'main': 68,
#  'types': 69,
#  'input': 70,
#  'difference': 71,
#  'variable': 72,
#  'random': 73,
#  'unseen': 74,
#  'be': 75,
#  'prevented': 76,
#  'tradeoff': 77,
#  'ability': 78,
#  'low': 79,
#  'decision': 80,
#  'tree': 81,
#  'questions': 82,
#  'curse': 83,
#  'dimensionality': 84,
#  'large': 85,
#  'feature': 86,
#  'engineering': 87,
#  'process': 88,
#  'human': 89,
#  'layers': 90,
#  'convolutional': 91,
#  'cnn': 92,
#  'specific': 93,
#  'batch': 94,
#  'normalization': 95,
#  'technique': 96,
#  'networks': 97,
#  'transfer': 98,
#  'task': 99,
#  'ensemble': 100,
#  'method': 101,
#  'combines': 102,
#  'e': 103,
#  'g': 104,
#  'natural': 105,
#  'nlp': 106,
#  'involves': 107,
#  'ratio': 108,
#  'sum': 109,
#  'false': 110,
#  'positive': 111,
#  'subset': 112,
#  'artificial': 113,
#  'intelligence': 114,
#  'development': 115,
#  'algorithms': 116,
#  'allow': 117,
#  'without': 118,
#  'being': 119,
#  'explicitly': 120,
#  'programmed': 121,
#  'labeled': 122,
#  'meaning': 123,
#  'pairs': 124,
#  'given': 125,
#  'unlabeled': 126,
#  'must': 127,
#  'discover': 128,
#  'patterns': 129,
#  'relationships': 130,
#  'own': 131,
#  'agent': 132,
#  'sequence': 133,
#  'interacting': 134,
#  'environment': 135,
#  'receives': 136,
#  'rewards': 137,
#  'penalties': 138,
#  'actions': 139,
#  'category': 140,
#  'label': 141,
#  'continuous': 142,
#  'value': 143,
#  'occurs': 144,
#  'too': 145,
#  'well': 146,
#  'point': 147,
#  'starts': 148,
#  'memorize': 149,
#  'noise': 150,
#  'fluctuations': 151,
#  'this': 152,
#  'leads': 153,
#  'poor': 154,
#  'how': 155,
#  'using': 156,
#  'cross': 157,
#  'validation': 158,
#  'regularization': 159,
#  'collecting': 160,
#  'more': 161,
#  'diverse': 162,
#  'balance': 163,
#  "model's": 164,
#  'fit': 165,
#  'closely': 166,
#  'generalize': 167,
#  'algorithm': 168,
#  'makes': 169,
#  'asking': 170,
#  'series': 171,
#  'about': 172,
#  'splits': 173,
#  'into': 174,
#  'branches': 175,
#  'these': 176,
#  'ultimately': 177,
#  'leading': 178,
#  'prediction': 179,
#  'refers': 180,
#  'challenges': 181,
#  'difficulties': 182,
#  'arise': 183,
#  'working': 184,
#  'high': 185,
#  'dimensional': 186,
#  'number': 187,
#  'dimensions': 188,
#  'very': 189,
#  'lead': 190,
#  'increased': 191,
#  'computational': 192,
#  'complexity': 193,
#  'need': 194,
#  'larger': 195,
#  'amounts': 196,
#  'selecting': 197,
#  'transforming': 198,
#  'creating': 199,
#  'new': 200,
#  'existing': 201,
#  'inspired': 202,
#  'structure': 203,
#  'functioning': 204,
#  'brain': 205,
#  'consists': 206,
#  'interconnected': 207,
#  'nodes': 208,
#  'neurons': 209,
#  'organized': 210,
#  "it's": 211,
#  'pattern': 212,
#  'recognition': 213,
#  'designed': 214,
#  'grid': 215,
#  'such': 216,
#  'as': 217,
#  'images': 218,
#  'uses': 219,
#  'convolution': 220,
#  'operations': 221,
#  'automatically': 222,
#  'adaptively': 223,
#  'purpose': 224,
#  'stability': 225,
#  'normalizes': 226,
#  'inputs': 227,
#  'layer': 228,
#  'helping': 229,
#  'reduce': 230,
#  'internal': 231,
#  'covariate': 232,
#  'shifts': 233,
#  'accelerate': 234,
#  'convergence': 235,
#  'pre': 236,
#  'originally': 237,
#  'fine': 238,
#  'tuned': 239,
#  'adapted': 240,
#  'different': 241,
#  'but': 242,
#  'related': 243,
#  'smaller': 244,
#  'multiple': 245,
#  'overall': 246,
#  'common': 247,
#  'include': 248,
#  'bagging': 249,
#  'forest': 250,
#  'boosting': 251,
#  'adaboost': 252,
#  'stacking': 253,
#  'field': 254,
#  'focused': 255,
#  'interaction': 256,
#  'translation': 257,
#  'sentiment': 258,
#  'analysis': 259,
#  'text': 260,
#  'generation': 261,
#  'negatives': 262,
#  'emphasizes': 263,
#  'accuracy': 264,
#  'finding': 265,
#  'all': 266,
#  'instances': 267,
#  'principles': 268,
#  'reward': 269,
#  'system': 270,
#  'often': 271,
#  'complex': 272,
#  'playing': 273,
#  'video': 274,
#  'games': 275,
#  'controlling': 276,
#  'autonomous': 277,
#  'systems': 278}

# %%
input_sequences = []
for sentence in faqs.split('\n'):
  tokenized_sentence = tokenizer.texts_to_sequences([sentence])[0]

  for i in range(1,len(tokenized_sentence)):
    input_sequences.append(tokenized_sentence[:i+1])

# %%
input_sequences
# Out:
# [[8, 1],
#  [8, 1, 9],
#  [8, 1, 9, 2],
#  [9, 2],
#  [9, 2, 1],
#  [9, 2, 1, 4],
#  [9, 2, 1, 4, 112],
#  [9, 2, 1, 4, 112, 5],
#  [9, 2, 1, 4, 112, 5, 113],
#  [9, 2, 1, 4, 112, 5, 113, 114],
#  [9, 2, 1, 4, 112, 5, 113, 114, 16],
#  [9, 2, 1, 4, 112, 5, 113, 114, 16, 62],
#  [9, 2, 1, 4, 112, 5, 113, 114, 16, 62, 13],
#  [9, 2, 1, 4, 112, 5, 113, 114, 16, 62, 13, 3],
#  [9, 2, 1, 4, 112, 5, 113, 114, 16, 62, 13, 3, 115],
#  [9, 2, 1, 4, 112, 5, 113, 114, 16, 62, 13, 3, 115, 5],
#  [9, 2, 1, 4, 112, 5, 113, 114, 16, 62, 13, 3, 115, 5, 116],
#  [9, 2, 1, 4, 112, 5, 113, 114, 16, 62, 13, 3, 115, 5, 116, 6],
#  [9, 2, 1, 4, 112, 5, 113, 114, 16, 62, 13, 3, 115, 5, 116, 6, 63],
#  [9, 2, 1, 4, 112, 5, 113, 114, 16, 62, 13, 3, 115, 5, 116, 6, 63, 16],
#  [9, 2, 1, 4, 112, 5, 113, 114, 16, 62, 13, 3, 115, 5, 116, 6, 63, 16, 117],
#  [9,
#   2,
#   1,
#   4,
#   112,
#   5,
#   113,
#   114,
#   16,
#   62,
#   13,
#   3,
#   115,
#   5,
#   116,
#   6,
#   63,
#   16,
#   117,
#   64],
#  [9,
#   2,
#   1,
#   4,
#   112,
#   5,
#   113,
#   114,
#   16,
#   62,
#   13,
#   3,
#   115,
#   5,
#   116,
#   6,
#   63,
#   16,
#   117,
#   64,
#   7],
#  [9,
#   2,
#   1,
#   4,
#   112,
#   5,
#   113,
#   114,
#   16,
#   62,
#   13,
#   3,
#   115,
#   5,
#   116,
#   6,
#   63,
#   16,
#   117,
#   64,
#   7,
#   65],
#  [9,
#   2,
#   1,
#   4,
#   112,
#   5,
#   113,
#   114,
#   16,
#   62,
#   13,
#   3,
#   115,
#   5,
#   116,
#   6,
#   63,
#   16,
#   117,
#   64,
#   7,
#   65,
#   6],
#  [9,
#   2,
#   1,
#   4,
#   112,
#   5,
#   113,
#   114,
#   16,
#   62,
#   13,
#   3,
#   115,
#   5,
#   116,
#   6,
#   63,
#   16,
#   117,
#   64,
#   7,
#   65,
#   6,
#   28],
#  [9,
#   2,
#   1,
#   4,
#   112,
#   5,
#   113,
#   114,
#   16,
#   62,
#   13,
#   3,
#   115,
#   5,
#   116,
#   6,
#   63,
#   16,
#   117,
#   64,
#   7,
#   65,
#   6,
#   28,
#   42],
#  [9,
#   2,
#   1,
#   4,
#   112,
#   5,
#   113,
#   114,
#   16,
#   62,
#   13,
#   3,
#   115,
#   5,
#   116,
#   6,
#   63,
#   16,
#   117,
#   64,
#   7,
#   65,
#   6,
#   28,
#   42,
#   14],
#  [9,
#   2,
#   1,
#   4,
#   112,
#   5,
#   113,
#   114,
#   16,
#   62,
#   13,
#   3,
#   115,
#   5,
#   116,
#   6,
#   63,
#   16,
#   117,
#   64,
#   7,
#   65,
#   6,
#   28,
#   42,
#   14,
#   29],
#  [9,
#   2,
#   1,
#   4,
#   112,
#   5,
#   113,
#   114,
#   16,
#   62,
#   13,
#   3,
#   115,
#   5,
#   116,
#   6,
#   63,
#   16,
#   117,
#   64,
#   7,
#   65,
#   6,
#   28,
#   42,
#   14,
#   29,
#   118],
#  [9,
#   2,
#   1,
#   4,
#   112,
#   5,
#   113,
#   114,
#   16,
#   62,
#   13,
#   3,
#   115,
#   5,
#   116,
#   6,
#   63,
#   16,
#   117,
#   64,
#   7,
#   65,
#   6,
#   28,
#   42,
#   14,
#   29,
#   118,
#   119],
#  [9,
#   2,
#   1,
#   4,
#   112,
#   5,
#   113,
#   114,
#   16,
#   62,
#   13,
#   3,
#   115,
#   5,
#   116,
#   6,
#   63,
#   16,
#   117,
#   64,
#   7,
#   65,
#   6,
#   28,
#   42,
#   14,
#   29,
#   118,
#   119,
#   120],
#  [9,
#   2,
#   1,
#   4,
#   112,
#   5,
#   113,
#   114,
#   16,
#   62,
#   13,
#   3,
#   115,
#   5,
#   116,
#   6,
#   63,
#   16,
#   117,
#   64,
#   7,
#   65,
#   6,
#   28,
#   42,
#   14,
#   29,
#   118,
#   119,
#   120,
#   121],
#  [8, 66],
#  [8, 66, 3],
#  [8, 66, 3, 67],
#  [8, 66, 3, 67, 68],
#  [8, 66, 3, 67, 68, 69],
#  [8, 66, 3, 67, 68, 69, 5],
#  [8, 66, 3, 67, 68, 69, 5, 9],
#  [8, 66, 3, 67, 68, 69, 5, 9, 2],
#  [3, 67],
#  [3, 67, 68],
#  [3, 67, 68, 69],
#  [3, 67, 68, 69, 5],
#  [3, 67, 68, 69, 5, 9],
#  [3, 67, 68, 69, 5, 9, 2],
#  [3, 67, 68, 69, 5, 9, 2, 66],
#  [3, 67, 68, 69, 5, 9, 2, 66, 30],
#  [3, 67, 68, 69, 5, 9, 2, 66, 30, 2],
#  [3, 67, 68, 69, 5, 9, 2, 66, 30, 2, 43],
#  [3, 67, 68, 69, 5, 9, 2, 66, 30, 2, 43, 2],
#  [3, 67, 68, 69, 5, 9, 2, 66, 30, 2, 43, 2, 6],
#  [3, 67, 68, 69, 5, 9, 2, 66, 30, 2, 43, 2, 6, 17],
#  [3, 67, 68, 69, 5, 9, 2, 66, 30, 2, 43, 2, 6, 17, 2],
#  [8, 1],
#  [8, 1, 30],
#  [8, 1, 30, 2],
#  [30, 2],
#  [30, 2, 1],
#  [30, 2, 1, 4],
#  [30, 2, 1, 4, 20],
#  [30, 2, 1, 4, 20, 5],
#  [30, 2, 1, 4, 20, 5, 9],
#  [30, 2, 1, 4, 20, 5, 9, 2],
#  [30, 2, 1, 4, 20, 5, 9, 2, 21],
#  [30, 2, 1, 4, 20, 5, 9, 2, 21, 3],
#  [30, 2, 1, 4, 20, 5, 9, 2, 21, 3, 18],
#  [30, 2, 1, 4, 20, 5, 9, 2, 21, 3, 18, 1],
#  [30, 2, 1, 4, 20, 5, 9, 2, 21, 3, 18, 1, 44],
#  [30, 2, 1, 4, 20, 5, 9, 2, 21, 3, 18, 1, 44, 13],
#  [30, 2, 1, 4, 20, 5, 9, 2, 21, 3, 18, 1, 44, 13, 4],
#  [30, 2, 1, 4, 20, 5, 9, 2, 21, 3, 18, 1, 44, 13, 4, 122],
#  [30, 2, 1, 4, 20, 5, 9, 2, 21, 3, 18, 1, 44, 13, 4, 122, 45],
#  [30, 2, 1, 4, 20, 5, 9, 2, 21, 3, 18, 1, 44, 13, 4, 122, 45, 123],
#  [30, 2, 1, 4, 20, 5, 9, 2, 21, 3, 18, 1, 44, 13, 4, 122, 45, 123, 16],
#  [30, 2, 1, 4, 20, 5, 9, 2, 21, 3, 18, 1, 44, 13, 4, 122, 45, 123, 16, 12],
#  [30, 2, 1, 4, 20, 5, 9, 2, 21, 3, 18, 1, 44, 13, 4, 122, 45, 123, 16, 12, 31],
#  [30,
#   2,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   21,
#   3,
#   18,
#   1,
#   44,
#   13,
#   4,
#   122,
#   45,
#   123,
#   16,
#   12,
#   31,
#   46],
#  [30,
#   2,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   21,
#   3,
#   18,
#   1,
#   44,
#   13,
#   4,
#   122,
#   45,
#   123,
#   16,
#   12,
#   31,
#   46,
#   70],
#  [30,
#   2,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   21,
#   3,
#   18,
#   1,
#   44,
#   13,
#   4,
#   122,
#   45,
#   123,
#   16,
#   12,
#   31,
#   46,
#   70,
#   47],
#  [30,
#   2,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   21,
#   3,
#   18,
#   1,
#   44,
#   13,
#   4,
#   122,
#   45,
#   123,
#   16,
#   12,
#   31,
#   46,
#   70,
#   47,
#   124],
#  [30,
#   2,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   21,
#   3,
#   18,
#   1,
#   44,
#   13,
#   4,
#   122,
#   45,
#   123,
#   16,
#   12,
#   31,
#   46,
#   70,
#   47,
#   124,
#   12],
#  [30,
#   2,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   21,
#   3,
#   18,
#   1,
#   44,
#   13,
#   4,
#   122,
#   45,
#   123,
#   16,
#   12,
#   31,
#   46,
#   70,
#   47,
#   124,
#   12,
#   31],
#  [30,
#   2,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   21,
#   3,
#   18,
#   1,
#   44,
#   13,
#   4,
#   122,
#   45,
#   123,
#   16,
#   12,
#   31,
#   46,
#   70,
#   47,
#   124,
#   12,
#   31,
#   7],
#  [30,
#   2,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   21,
#   3,
#   18,
#   1,
#   44,
#   13,
#   4,
#   122,
#   45,
#   123,
#   16,
#   12,
#   31,
#   46,
#   70,
#   47,
#   124,
#   12,
#   31,
#   7,
#   28],
#  [30,
#   2,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   21,
#   3,
#   18,
#   1,
#   44,
#   13,
#   4,
#   122,
#   45,
#   123,
#   16,
#   12,
#   31,
#   46,
#   70,
#   47,
#   124,
#   12,
#   31,
#   7,
#   28,
#   42],
#  [30,
#   2,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   21,
#   3,
#   18,
#   1,
#   44,
#   13,
#   4,
#   122,
#   45,
#   123,
#   16,
#   12,
#   31,
#   46,
#   70,
#   47,
#   124,
#   12,
#   31,
#   7,
#   28,
#   42,
#   48],
#  [30,
#   2,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   21,
#   3,
#   18,
#   1,
#   44,
#   13,
#   4,
#   122,
#   45,
#   123,
#   16,
#   12,
#   31,
#   46,
#   70,
#   47,
#   124,
#   12,
#   31,
#   7,
#   28,
#   42,
#   48,
#   13],
#  [30,
#   2,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   21,
#   3,
#   18,
#   1,
#   44,
#   13,
#   4,
#   122,
#   45,
#   123,
#   16,
#   12,
#   31,
#   46,
#   70,
#   47,
#   124,
#   12,
#   31,
#   7,
#   28,
#   42,
#   48,
#   13,
#   70],
#  [30,
#   2,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   21,
#   3,
#   18,
#   1,
#   44,
#   13,
#   4,
#   122,
#   45,
#   123,
#   16,
#   12,
#   31,
#   46,
#   70,
#   47,
#   124,
#   12,
#   31,
#   7,
#   28,
#   42,
#   48,
#   13,
#   70,
#   10],
#  [8, 1],
#  [8, 1, 43],
#  [8, 1, 43, 2],
#  [43, 2],
#  [43, 2, 1],
#  [43, 2, 1, 4],
#  [43, 2, 1, 4, 20],
#  [43, 2, 1, 4, 20, 5],
#  [43, 2, 1, 4, 20, 5, 9],
#  [43, 2, 1, 4, 20, 5, 9, 2],
#  [43, 2, 1, 4, 20, 5, 9, 2, 21],
#  [43, 2, 1, 4, 20, 5, 9, 2, 21, 3],
#  [43, 2, 1, 4, 20, 5, 9, 2, 21, 3, 18],
#  [43, 2, 1, 4, 20, 5, 9, 2, 21, 3, 18, 1],
#  [43, 2, 1, 4, 20, 5, 9, 2, 21, 3, 18, 1, 125],
#  [43, 2, 1, 4, 20, 5, 9, 2, 21, 3, 18, 1, 125, 126],
#  [43, 2, 1, 4, 20, 5, 9, 2, 21, 3, 18, 1, 125, 126, 10],
#  [43, 2, 1, 4, 20, 5, 9, 2, 21, 3, 18, 1, 125, 126, 10, 6],
#  [43, 2, 1, 4, 20, 5, 9, 2, 21, 3, 18, 1, 125, 126, 10, 6, 127],
#  [43, 2, 1, 4, 20, 5, 9, 2, 21, 3, 18, 1, 125, 126, 10, 6, 127, 128],
#  [43, 2, 1, 4, 20, 5, 9, 2, 21, 3, 18, 1, 125, 126, 10, 6, 127, 128, 129],
#  [43, 2, 1, 4, 20, 5, 9, 2, 21, 3, 18, 1, 125, 126, 10, 6, 127, 128, 129, 6],
#  [43,
#   2,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   21,
#   3,
#   18,
#   1,
#   125,
#   126,
#   10,
#   6,
#   127,
#   128,
#   129,
#   6,
#   130],
#  [43,
#   2,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   21,
#   3,
#   18,
#   1,
#   125,
#   126,
#   10,
#   6,
#   127,
#   128,
#   129,
#   6,
#   130,
#   13],
#  [43,
#   2,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   21,
#   3,
#   18,
#   1,
#   125,
#   126,
#   10,
#   6,
#   127,
#   128,
#   129,
#   6,
#   130,
#   13,
#   49],
#  [43,
#   2,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   21,
#   3,
#   18,
#   1,
#   125,
#   126,
#   10,
#   6,
#   127,
#   128,
#   129,
#   6,
#   130,
#   13,
#   49,
#   131],
#  [8, 1],
#  [8, 1, 17],
#  [8, 1, 17, 2],
#  [17, 2],
#  [17, 2, 1],
#  [17, 2, 1, 4],
#  [17, 2, 1, 4, 20],
#  [17, 2, 1, 4, 20, 5],
#  [17, 2, 1, 4, 20, 5, 9],
#  [17, 2, 1, 4, 20, 5, 9, 2],
#  [17, 2, 1, 4, 20, 5, 9, 2, 21],
#  [17, 2, 1, 4, 20, 5, 9, 2, 21, 32],
#  [17, 2, 1, 4, 20, 5, 9, 2, 21, 32, 132],
#  [17, 2, 1, 4, 20, 5, 9, 2, 21, 32, 132, 31],
#  [17, 2, 1, 4, 20, 5, 9, 2, 21, 32, 132, 31, 7],
#  [17, 2, 1, 4, 20, 5, 9, 2, 21, 32, 132, 31, 7, 28],
#  [17, 2, 1, 4, 20, 5, 9, 2, 21, 32, 132, 31, 7, 28, 4],
#  [17, 2, 1, 4, 20, 5, 9, 2, 21, 32, 132, 31, 7, 28, 4, 133],
#  [17, 2, 1, 4, 20, 5, 9, 2, 21, 32, 132, 31, 7, 28, 4, 133, 5],
#  [17, 2, 1, 4, 20, 5, 9, 2, 21, 32, 132, 31, 7, 28, 4, 133, 5, 29],
#  [17, 2, 1, 4, 20, 5, 9, 2, 21, 32, 132, 31, 7, 28, 4, 133, 5, 29, 33],
#  [17, 2, 1, 4, 20, 5, 9, 2, 21, 32, 132, 31, 7, 28, 4, 133, 5, 29, 33, 134],
#  [17,
#   2,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   21,
#   32,
#   132,
#   31,
#   7,
#   28,
#   4,
#   133,
#   5,
#   29,
#   33,
#   134,
#   34],
#  [17,
#   2,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   21,
#   32,
#   132,
#   31,
#   7,
#   28,
#   4,
#   133,
#   5,
#   29,
#   33,
#   134,
#   34,
#   32],
#  [17,
#   2,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   21,
#   32,
#   132,
#   31,
#   7,
#   28,
#   4,
#   133,
#   5,
#   29,
#   33,
#   134,
#   34,
#   32,
#   135],
#  [17,
#   2,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   21,
#   32,
#   132,
#   31,
#   7,
#   28,
#   4,
#   133,
#   5,
#   29,
#   33,
#   134,
#   34,
#   32,
#   135,
#   12],
#  [17,
#   2,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   21,
#   32,
#   132,
#   31,
#   7,
#   28,
#   4,
#   133,
#   5,
#   29,
#   33,
#   134,
#   34,
#   32,
#   135,
#   12,
#   136],
#  [17,
#   2,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   21,
#   32,
#   132,
#   31,
#   7,
#   28,
#   4,
#   133,
#   5,
#   29,
#   33,
#   134,
#   34,
#   32,
#   135,
#   12,
#   136,
#   137],
#  [17,
#   2,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   21,
#   32,
#   132,
#   31,
#   7,
#   28,
#   4,
#   133,
#   5,
#   29,
#   33,
#   134,
#   34,
#   32,
#   135,
#   12,
#   136,
#   137,
#   14],
#  [17,
#   2,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   21,
#   32,
#   132,
#   31,
#   7,
#   28,
#   4,
#   133,
#   5,
#   29,
#   33,
#   134,
#   34,
#   32,
#   135,
#   12,
#   136,
#   137,
#   14,
#   138],
#  [17,
#   2,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   21,
#   32,
#   132,
#   31,
#   7,
#   28,
#   4,
#   133,
#   5,
#   29,
#   33,
#   134,
#   34,
#   32,
#   135,
#   12,
#   136,
#   137,
#   14,
#   138,
#   19],
#  [17,
#   2,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   21,
#   32,
#   132,
#   31,
#   7,
#   28,
#   4,
#   133,
#   5,
#   29,
#   33,
#   134,
#   34,
#   32,
#   135,
#   12,
#   136,
#   137,
#   14,
#   138,
#   19,
#   49],
#  [17,
#   2,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   21,
#   32,
#   132,
#   31,
#   7,
#   28,
#   4,
#   133,
#   5,
#   29,
#   33,
#   134,
#   34,
#   32,
#   135,
#   12,
#   136,
#   137,
#   14,
#   138,
#   19,
#   49,
#   139],
#  [8, 1],
#  [8, 1, 3],
#  [8, 1, 3, 71],
#  [8, 1, 3, 71, 35],
#  [8, 1, 3, 71, 35, 36],
#  [8, 1, 3, 71, 35, 36, 6],
#  [8, 1, 3, 71, 35, 36, 6, 50],
#  [8, 1, 3, 71, 35, 36, 6, 50, 11],
#  [8, 1, 3, 71, 35, 36, 6, 50, 11, 9],
#  [8, 1, 3, 71, 35, 36, 6, 50, 11, 9, 2],
#  [36, 1],
#  [36, 1, 22],
#  [36, 1, 22, 37],
#  [36, 1, 22, 37, 3],
#  [36, 1, 22, 37, 3, 47],
#  [36, 1, 22, 37, 3, 47, 72],
#  [36, 1, 22, 37, 3, 47, 72, 1],
#  [36, 1, 22, 37, 3, 47, 72, 1, 4],
#  [36, 1, 22, 37, 3, 47, 72, 1, 4, 140],
#  [36, 1, 22, 37, 3, 47, 72, 1, 4, 140, 14],
#  [36, 1, 22, 37, 3, 47, 72, 1, 4, 140, 14, 141],
#  [36, 1, 22, 37, 3, 47, 72, 1, 4, 140, 14, 141, 51],
#  [36, 1, 22, 37, 3, 47, 72, 1, 4, 140, 14, 141, 51, 50],
#  [36, 1, 22, 37, 3, 47, 72, 1, 4, 140, 14, 141, 51, 50, 1],
#  [36, 1, 22, 37, 3, 47, 72, 1, 4, 140, 14, 141, 51, 50, 1, 22],
#  [36, 1, 22, 37, 3, 47, 72, 1, 4, 140, 14, 141, 51, 50, 1, 22, 37],
#  [36, 1, 22, 37, 3, 47, 72, 1, 4, 140, 14, 141, 51, 50, 1, 22, 37, 3],
#  [36, 1, 22, 37, 3, 47, 72, 1, 4, 140, 14, 141, 51, 50, 1, 22, 37, 3, 47],
#  [36, 1, 22, 37, 3, 47, 72, 1, 4, 140, 14, 141, 51, 50, 1, 22, 37, 3, 47, 72],
#  [36,
#   1,
#   22,
#   37,
#   3,
#   47,
#   72,
#   1,
#   4,
#   140,
#   14,
#   141,
#   51,
#   50,
#   1,
#   22,
#   37,
#   3,
#   47,
#   72,
#   1],
#  [36,
#   1,
#   22,
#   37,
#   3,
#   47,
#   72,
#   1,
#   4,
#   140,
#   14,
#   141,
#   51,
#   50,
#   1,
#   22,
#   37,
#   3,
#   47,
#   72,
#   1,
#   4],
#  [36,
#   1,
#   22,
#   37,
#   3,
#   47,
#   72,
#   1,
#   4,
#   140,
#   14,
#   141,
#   51,
#   50,
#   1,
#   22,
#   37,
#   3,
#   47,
#   72,
#   1,
#   4,
#   142],
#  [36,
#   1,
#   22,
#   37,
#   3,
#   47,
#   72,
#   1,
#   4,
#   140,
#   14,
#   141,
#   51,
#   50,
#   1,
#   22,
#   37,
#   3,
#   47,
#   72,
#   1,
#   4,
#   142,
#   143],
#  [8, 1],
#  [8, 1, 38],
#  [8, 1, 38, 11],
#  [8, 1, 38, 11, 9],
#  [8, 1, 38, 11, 9, 2],
#  [38, 144],
#  [38, 144, 37],
#  [38, 144, 37, 4],
#  [38, 144, 37, 4, 18],
#  [38, 144, 37, 4, 18, 31],
#  [38, 144, 37, 4, 18, 31, 3],
#  [38, 144, 37, 4, 18, 31, 3, 23],
#  [38, 144, 37, 4, 18, 31, 3, 23, 10],
#  [38, 144, 37, 4, 18, 31, 3, 23, 10, 145],
#  [38, 144, 37, 4, 18, 31, 3, 23, 10, 145, 146],
#  [38, 144, 37, 4, 18, 31, 3, 23, 10, 145, 146, 7],
#  [38, 144, 37, 4, 18, 31, 3, 23, 10, 145, 146, 7, 3],
#  [38, 144, 37, 4, 18, 31, 3, 23, 10, 145, 146, 7, 3, 147],
#  [38, 144, 37, 4, 18, 31, 3, 23, 10, 145, 146, 7, 3, 147, 16],
#  [38, 144, 37, 4, 18, 31, 3, 23, 10, 145, 146, 7, 3, 147, 16, 12],
#  [38, 144, 37, 4, 18, 31, 3, 23, 10, 145, 146, 7, 3, 147, 16, 12, 148],
#  [38, 144, 37, 4, 18, 31, 3, 23, 10, 145, 146, 7, 3, 147, 16, 12, 148, 7],
#  [38, 144, 37, 4, 18, 31, 3, 23, 10, 145, 146, 7, 3, 147, 16, 12, 148, 7, 149],
#  [38,
#   144,
#   37,
#   4,
#   18,
#   31,
#   3,
#   23,
#   10,
#   145,
#   146,
#   7,
#   3,
#   147,
#   16,
#   12,
#   148,
#   7,
#   149,
#   150],
#  [38,
#   144,
#   37,
#   4,
#   18,
#   31,
#   3,
#   23,
#   10,
#   145,
#   146,
#   7,
#   3,
#   147,
#   16,
#   12,
#   148,
#   7,
#   149,
#   150,
#   14],
#  [38,
#   144,
#   37,
#   4,
#   18,
#   31,
#   3,
#   23,
#   10,
#   145,
#   146,
#   7,
#   3,
#   147,
#   16,
#   12,
#   148,
#   7,
#   149,
#   150,
#   14,
#   73],
#  [38,
#   144,
#   37,
#   4,
#   18,
#   31,
#   3,
#   23,
#   10,
#   145,
#   146,
#   7,
#   3,
#   147,
#   16,
#   12,
#   148,
#   7,
#   149,
#   150,
#   14,
#   73,
#   151],
#  [38,
#   144,
#   37,
#   4,
#   18,
#   31,
#   3,
#   23,
#   10,
#   145,
#   146,
#   7,
#   3,
#   147,
#   16,
#   12,
#   148,
#   7,
#   149,
#   150,
#   14,
#   73,
#   151,
#   152],
#  [38,
#   144,
#   37,
#   4,
#   18,
#   31,
#   3,
#   23,
#   10,
#   145,
#   146,
#   7,
#   3,
#   147,
#   16,
#   12,
#   148,
#   7,
#   149,
#   150,
#   14,
#   73,
#   151,
#   152,
#   153],
#  [38,
#   144,
#   37,
#   4,
#   18,
#   31,
#   3,
#   23,
#   10,
#   145,
#   146,
#   7,
#   3,
#   147,
#   16,
#   12,
#   148,
#   7,
#   149,
#   150,
#   14,
#   73,
#   151,
#   152,
#   153,
#   7],
#  [38,
#   144,
#   37,
#   4,
#   18,
#   31,
#   3,
#   23,
#   10,
#   145,
#   146,
#   7,
#   3,
#   147,
#   16,
#   12,
#   148,
#   7,
#   149,
#   150,
#   14,
#   73,
#   151,
#   152,
#   153,
#   7,
#   154],
#  [38,
#   144,
#   37,
#   4,
#   18,
#   31,
#   3,
#   23,
#   10,
#   145,
#   146,
#   7,
#   3,
#   147,
#   16,
#   12,
#   148,
#   7,
#   149,
#   150,
#   14,
#   73,
#   151,
#   152,
#   153,
#   7,
#   154,
#   52],
#  [38,
#   144,
#   37,
#   4,
#   18,
#   31,
#   3,
#   23,
#   10,
#   145,
#   146,
#   7,
#   3,
#   147,
#   16,
#   12,
#   148,
#   7,
#   149,
#   150,
#   14,
#   73,
#   151,
#   152,
#   153,
#   7,
#   154,
#   52,
#   13],
#  [38,
#   144,
#   37,
#   4,
#   18,
#   31,
#   3,
#   23,
#   10,
#   145,
#   146,
#   7,
#   3,
#   147,
#   16,
#   12,
#   148,
#   7,
#   149,
#   150,
#   14,
#   73,
#   151,
#   152,
#   153,
#   7,
#   154,
#   52,
#   13,
#   74],
#  [38,
#   144,
#   37,
#   4,
#   18,
#   31,
#   3,
#   23,
#   10,
#   145,
#   146,
#   7,
#   3,
#   147,
#   16,
#   12,
#   148,
#   7,
#   149,
#   150,
#   14,
#   73,
#   151,
#   152,
#   153,
#   7,
#   154,
#   52,
#   13,
#   74,
#   10],
#  [155, 53],
#  [155, 53, 38],
#  [155, 53, 38, 75],
#  [155, 53, 38, 75, 76],
#  [38, 53],
#  [38, 53, 75],
#  [38, 53, 75, 76],
#  [38, 53, 75, 76, 33],
#  [38, 53, 75, 76, 33, 156],
#  [38, 53, 75, 76, 33, 156, 54],
#  [38, 53, 75, 76, 33, 156, 54, 24],
#  [38, 53, 75, 76, 33, 156, 54, 24, 157],
#  [38, 53, 75, 76, 33, 156, 54, 24, 157, 158],
#  [38, 53, 75, 76, 33, 156, 54, 24, 157, 158, 159],
#  [38, 53, 75, 76, 33, 156, 54, 24, 157, 158, 159, 6],
#  [38, 53, 75, 76, 33, 156, 54, 24, 157, 158, 159, 6, 160],
#  [38, 53, 75, 76, 33, 156, 54, 24, 157, 158, 159, 6, 160, 161],
#  [38, 53, 75, 76, 33, 156, 54, 24, 157, 158, 159, 6, 160, 161, 162],
#  [38, 53, 75, 76, 33, 156, 54, 24, 157, 158, 159, 6, 160, 161, 162, 23],
#  [38, 53, 75, 76, 33, 156, 54, 24, 157, 158, 159, 6, 160, 161, 162, 23, 10],
#  [8, 1],
#  [8, 1, 3],
#  [8, 1, 3, 55],
#  [8, 1, 3, 55, 56],
#  [8, 1, 3, 55, 56, 77],
#  [3, 55],
#  [3, 55, 56],
#  [3, 55, 56, 77],
#  [3, 55, 56, 77, 1],
#  [3, 55, 56, 77, 1, 3],
#  [3, 55, 56, 77, 1, 3, 163],
#  [3, 55, 56, 77, 1, 3, 163, 35],
#  [3, 55, 56, 77, 1, 3, 163, 35, 4],
#  [3, 55, 56, 77, 1, 3, 163, 35, 4, 164],
#  [3, 55, 56, 77, 1, 3, 163, 35, 4, 164, 78],
#  [3, 55, 56, 77, 1, 3, 163, 35, 4, 164, 78, 7],
#  [3, 55, 56, 77, 1, 3, 163, 35, 4, 164, 78, 7, 165],
#  [3, 55, 56, 77, 1, 3, 163, 35, 4, 164, 78, 7, 165, 3],
#  [3, 55, 56, 77, 1, 3, 163, 35, 4, 164, 78, 7, 165, 3, 23],
#  [3, 55, 56, 77, 1, 3, 163, 35, 4, 164, 78, 7, 165, 3, 23, 10],
#  [3, 55, 56, 77, 1, 3, 163, 35, 4, 164, 78, 7, 165, 3, 23, 10, 166],
#  [3, 55, 56, 77, 1, 3, 163, 35, 4, 164, 78, 7, 165, 3, 23, 10, 166, 79],
#  [3, 55, 56, 77, 1, 3, 163, 35, 4, 164, 78, 7, 165, 3, 23, 10, 166, 79, 55],
#  [3, 55, 56, 77, 1, 3, 163, 35, 4, 164, 78, 7, 165, 3, 23, 10, 166, 79, 55, 6],
#  [3,
#   55,
#   56,
#   77,
#   1,
#   3,
#   163,
#   35,
#   4,
#   164,
#   78,
#   7,
#   165,
#   3,
#   23,
#   10,
#   166,
#   79,
#   55,
#   6,
#   49],
#  [3,
#   55,
#   56,
#   77,
#   1,
#   3,
#   163,
#   35,
#   4,
#   164,
#   78,
#   7,
#   165,
#   3,
#   23,
#   10,
#   166,
#   79,
#   55,
#   6,
#   49,
#   78],
#  [3,
#   55,
#   56,
#   77,
#   1,
#   3,
#   163,
#   35,
#   4,
#   164,
#   78,
#   7,
#   165,
#   3,
#   23,
#   10,
#   166,
#   79,
#   55,
#   6,
#   49,
#   78,
#   7],
#  [3,
#   55,
#   56,
#   77,
#   1,
#   3,
#   163,
#   35,
#   4,
#   164,
#   78,
#   7,
#   165,
#   3,
#   23,
#   10,
#   166,
#   79,
#   55,
#   6,
#   49,
#   78,
#   7,
#   167],
#  [3,
#   55,
#   56,
#   77,
#   1,
#   3,
#   163,
#   35,
#   4,
#   164,
#   78,
#   7,
#   165,
#   3,
#   23,
#   10,
#   166,
#   79,
#   55,
#   6,
#   49,
#   78,
#   7,
#   167,
#   7],
#  [3,
#   55,
#   56,
#   77,
#   1,
#   3,
#   163,
#   35,
#   4,
#   164,
#   78,
#   7,
#   165,
#   3,
#   23,
#   10,
#   166,
#   79,
#   55,
#   6,
#   49,
#   78,
#   7,
#   167,
#   7,
#   74],
#  [3,
#   55,
#   56,
#   77,
#   1,
#   3,
#   163,
#   35,
#   4,
#   164,
#   78,
#   7,
#   165,
#   3,
#   23,
#   10,
#   166,
#   79,
#   55,
#   6,
#   49,
#   78,
#   7,
#   167,
#   7,
#   74,
#   10],
#  [3,
#   55,
#   56,
#   77,
#   1,
#   3,
#   163,
#   35,
#   4,
#   164,
#   78,
#   7,
#   165,
#   3,
#   23,
#   10,
#   166,
#   79,
#   55,
#   6,
#   49,
#   78,
#   7,
#   167,
#   7,
#   74,
#   10,
#   79],
#  [3,
#   55,
#   56,
#   77,
#   1,
#   3,
#   163,
#   35,
#   4,
#   164,
#   78,
#   7,
#   165,
#   3,
#   23,
#   10,
#   166,
#   79,
#   55,
#   6,
#   49,
#   78,
#   7,
#   167,
#   7,
#   74,
#   10,
#   79,
#   56],
#  [8, 1],
#  [8, 1, 4],
#  [8, 1, 4, 80],
#  [8, 1, 4, 80, 81],
#  [8, 1, 4, 80, 81, 11],
#  [8, 1, 4, 80, 81, 11, 9],
#  [8, 1, 4, 80, 81, 11, 9, 2],
#  [4, 80],
#  [4, 80, 81],
#  [4, 80, 81, 1],
#  [4, 80, 81, 1, 4],
#  [4, 80, 81, 1, 4, 30],
#  [4, 80, 81, 1, 4, 30, 2],
#  [4, 80, 81, 1, 4, 30, 2, 168],
#  [4, 80, 81, 1, 4, 30, 2, 168, 16],
#  [4, 80, 81, 1, 4, 30, 2, 168, 16, 169],
#  [4, 80, 81, 1, 4, 30, 2, 168, 16, 169, 29],
#  [4, 80, 81, 1, 4, 30, 2, 168, 16, 169, 29, 33],
#  [4, 80, 81, 1, 4, 30, 2, 168, 16, 169, 29, 33, 170],
#  [4, 80, 81, 1, 4, 30, 2, 168, 16, 169, 29, 33, 170, 4],
#  [4, 80, 81, 1, 4, 30, 2, 168, 16, 169, 29, 33, 170, 4, 171],
#  [4, 80, 81, 1, 4, 30, 2, 168, 16, 169, 29, 33, 170, 4, 171, 5],
#  [4, 80, 81, 1, 4, 30, 2, 168, 16, 169, 29, 33, 170, 4, 171, 5, 82],
#  [4, 80, 81, 1, 4, 30, 2, 168, 16, 169, 29, 33, 170, 4, 171, 5, 82, 172],
#  [4, 80, 81, 1, 4, 30, 2, 168, 16, 169, 29, 33, 170, 4, 171, 5, 82, 172, 3],
#  [4,
#   80,
#   81,
#   1,
#   4,
#   30,
#   2,
#   168,
#   16,
#   169,
#   29,
#   33,
#   170,
#   4,
#   171,
#   5,
#   82,
#   172,
#   3,
#   39],
#  [4,
#   80,
#   81,
#   1,
#   4,
#   30,
#   2,
#   168,
#   16,
#   169,
#   29,
#   33,
#   170,
#   4,
#   171,
#   5,
#   82,
#   172,
#   3,
#   39,
#   5],
#  [4,
#   80,
#   81,
#   1,
#   4,
#   30,
#   2,
#   168,
#   16,
#   169,
#   29,
#   33,
#   170,
#   4,
#   171,
#   5,
#   82,
#   172,
#   3,
#   39,
#   5,
#   3],
#  [4,
#   80,
#   81,
#   1,
#   4,
#   30,
#   2,
#   168,
#   16,
#   169,
#   29,
#   33,
#   170,
#   4,
#   171,
#   5,
#   82,
#   172,
#   3,
#   39,
#   5,
#   3,
#   10],
#  [4,
#   80,
#   81,
#   1,
#   4,
#   30,
#   2,
#   168,
#   16,
#   169,
#   29,
#   33,
#   170,
#   4,
#   171,
#   5,
#   82,
#   172,
#   3,
#   39,
#   5,
#   3,
#   10,
#   12],
#  [4,
#   80,
#   81,
#   1,
#   4,
#   30,
#   2,
#   168,
#   16,
#   169,
#   29,
#   33,
#   170,
#   4,
#   171,
#   5,
#   82,
#   172,
#   3,
#   39,
#   5,
#   3,
#   10,
#   12,
#   173],
#  [4,
#   80,
#   81,
#   1,
#   4,
#   30,
#   2,
#   168,
#   16,
#   169,
#   29,
#   33,
#   170,
#   4,
#   171,
#   5,
#   82,
#   172,
#   3,
#   39,
#   5,
#   3,
#   10,
#   12,
#   173,
#   3],
#  [4,
#   80,
#   81,
#   1,
#   4,
#   30,
#   2,
#   168,
#   16,
#   169,
#   29,
#   33,
#   170,
#   4,
#   171,
#   5,
#   82,
#   172,
#   3,
#   39,
#   5,
#   3,
#   10,
#   12,
#   173,
#   3,
#   10],
#  [4,
#   80,
#   81,
#   1,
#   4,
#   30,
#   2,
#   168,
#   16,
#   169,
#   29,
#   33,
#   170,
#   4,
#   171,
#   5,
#   82,
#   172,
#   3,
#   39,
#   5,
#   3,
#   10,
#   12,
#   173,
#   3,
#   10,
#   174],
#  [4,
#   80,
#   81,
#   1,
#   4,
#   30,
#   2,
#   168,
#   16,
#   169,
#   29,
#   33,
#   170,
#   4,
#   171,
#   5,
#   82,
#   172,
#   3,
#   39,
#   5,
#   3,
#   10,
#   12,
#   173,
#   3,
#   10,
#   174,
#   175],
#  [4,
#   80,
#   81,
#   1,
#   4,
#   30,
#   2,
#   168,
#   16,
#   169,
#   29,
#   33,
#   170,
#   4,
#   171,
#   5,
#   82,
#   172,
#   3,
#   39,
#   5,
#   3,
#   10,
#   12,
#   173,
#   3,
#   10,
#   174,
#   175,
#   48],
#  [4,
#   80,
#   81,
#   1,
#   4,
#   30,
#   2,
#   168,
#   16,
#   169,
#   29,
#   33,
#   170,
#   4,
#   171,
#   5,
#   82,
#   172,
#   3,
#   39,
#   5,
#   3,
#   10,
#   12,
#   173,
#   3,
#   10,
#   174,
#   175,
#   48,
#   13],
#  [4,
#   80,
#   81,
#   1,
#   4,
#   30,
#   2,
#   168,
#   16,
#   169,
#   29,
#   33,
#   170,
#   4,
#   171,
#   5,
#   82,
#   172,
#   3,
#   39,
#   5,
#   3,
#   10,
#   12,
#   173,
#   3,
#   10,
#   174,
#   175,
#   48,
#   13,
#   176],
#  [4,
#   80,
#   81,
#   1,
#   4,
#   30,
#   2,
#   168,
#   16,
#   169,
#   29,
#   33,
#   170,
#   4,
#   171,
#   5,
#   82,
#   172,
#   3,
#   39,
#   5,
#   3,
#   10,
#   12,
#   173,
#   3,
#   10,
#   174,
#   175,
#   48,
#   13,
#   176,
#   82],
#  [4,
#   80,
#   81,
#   1,
#   4,
#   30,
#   2,
#   168,
#   16,
#   169,
#   29,
#   33,
#   170,
#   4,
#   171,
#   5,
#   82,
#   172,
#   3,
#   39,
#   5,
#   3,
#   10,
#   12,
#   173,
#   3,
#   10,
#   174,
#   175,
#   48,
#   13,
#   176,
#   82,
#   177],
#  [4,
#   80,
#   81,
#   1,
#   4,
#   30,
#   2,
#   168,
#   16,
#   169,
#   29,
#   33,
#   170,
#   4,
#   171,
#   5,
#   82,
#   172,
#   3,
#   39,
#   5,
#   3,
#   10,
#   12,
#   173,
#   3,
#   10,
#   174,
#   175,
#   48,
#   13,
#   176,
#   82,
#   177,
#   178],
#  [4,
#   80,
#   81,
#   1,
#   4,
#   30,
#   2,
#   168,
#   16,
#   169,
#   29,
#   33,
#   170,
#   4,
#   171,
#   5,
#   82,
#   172,
#   3,
#   39,
#   5,
#   3,
#   10,
#   12,
#   173,
#   3,
#   10,
#   174,
#   175,
#   48,
#   13,
#   176,
#   82,
#   177,
#   178,
#   7],
#  [4,
#   80,
#   81,
#   1,
#   4,
#   30,
#   2,
#   168,
#   16,
#   169,
#   29,
#   33,
#   170,
#   4,
#   171,
#   5,
#   82,
#   172,
#   3,
#   39,
#   5,
#   3,
#   10,
#   12,
#   173,
#   3,
#   10,
#   174,
#   175,
#   48,
#   13,
#   176,
#   82,
#   177,
#   178,
#   7,
#   4],
#  [4,
#   80,
#   81,
#   1,
#   4,
#   30,
#   2,
#   168,
#   16,
#   169,
#   29,
#   33,
#   170,
#   4,
#   171,
#   5,
#   82,
#   172,
#   3,
#   39,
#   5,
#   3,
#   10,
#   12,
#   173,
#   3,
#   10,
#   174,
#   175,
#   48,
#   13,
#   176,
#   82,
#   177,
#   178,
#   7,
#   4,
#   179],
#  [8, 1],
#  [8, 1, 3],
#  [8, 1, 3, 83],
#  [8, 1, 3, 83, 5],
#  [8, 1, 3, 83, 5, 84],
#  [8, 1, 3, 83, 5, 84, 11],
#  [8, 1, 3, 83, 5, 84, 11, 9],
#  [8, 1, 3, 83, 5, 84, 11, 9, 2],
#  [3, 83],
#  [3, 83, 5],
#  [3, 83, 5, 84],
#  [3, 83, 5, 84, 180],
#  [3, 83, 5, 84, 180, 7],
#  [3, 83, 5, 84, 180, 7, 3],
#  [3, 83, 5, 84, 180, 7, 3, 181],
#  [3, 83, 5, 84, 180, 7, 3, 181, 6],
#  [3, 83, 5, 84, 180, 7, 3, 181, 6, 182],
#  [3, 83, 5, 84, 180, 7, 3, 181, 6, 182, 16],
#  [3, 83, 5, 84, 180, 7, 3, 181, 6, 182, 16, 183],
#  [3, 83, 5, 84, 180, 7, 3, 181, 6, 182, 16, 183, 37],
#  [3, 83, 5, 84, 180, 7, 3, 181, 6, 182, 16, 183, 37, 184],
#  [3, 83, 5, 84, 180, 7, 3, 181, 6, 182, 16, 183, 37, 184, 34],
#  [3, 83, 5, 84, 180, 7, 3, 181, 6, 182, 16, 183, 37, 184, 34, 185],
#  [3, 83, 5, 84, 180, 7, 3, 181, 6, 182, 16, 183, 37, 184, 34, 185, 186],
#  [3, 83, 5, 84, 180, 7, 3, 181, 6, 182, 16, 183, 37, 184, 34, 185, 186, 10],
#  [3,
#   83,
#   5,
#   84,
#   180,
#   7,
#   3,
#   181,
#   6,
#   182,
#   16,
#   183,
#   37,
#   184,
#   34,
#   185,
#   186,
#   10,
#   21],
#  [3,
#   83,
#   5,
#   84,
#   180,
#   7,
#   3,
#   181,
#   6,
#   182,
#   16,
#   183,
#   37,
#   184,
#   34,
#   185,
#   186,
#   10,
#   21,
#   3],
#  [3,
#   83,
#   5,
#   84,
#   180,
#   7,
#   3,
#   181,
#   6,
#   182,
#   16,
#   183,
#   37,
#   184,
#   34,
#   185,
#   186,
#   10,
#   21,
#   3,
#   187],
#  [3,
#   83,
#   5,
#   84,
#   180,
#   7,
#   3,
#   181,
#   6,
#   182,
#   16,
#   183,
#   37,
#   184,
#   34,
#   185,
#   186,
#   10,
#   21,
#   3,
#   187,
#   5],
#  [3,
#   83,
#   5,
#   84,
#   180,
#   7,
#   3,
#   181,
#   6,
#   182,
#   16,
#   183,
#   37,
#   184,
#   34,
#   185,
#   186,
#   10,
#   21,
#   3,
#   187,
#   5,
#   39],
#  [3,
#   83,
#   5,
#   84,
#   180,
#   7,
#   3,
#   181,
#   6,
#   182,
#   16,
#   183,
#   37,
#   184,
#   34,
#   185,
#   186,
#   10,
#   21,
#   3,
#   187,
#   5,
#   39,
#   14],
#  [3,
#   83,
#   5,
#   84,
#   180,
#   7,
#   3,
#   181,
#   6,
#   182,
#   16,
#   183,
#   37,
#   184,
#   34,
#   185,
#   186,
#   10,
#   21,
#   3,
#   187,
#   5,
#   39,
#   14,
#   188],
#  [3,
#   83,
#   5,
#   84,
#   180,
#   7,
#   3,
#   181,
#   6,
#   182,
#   16,
#   183,
#   37,
#   184,
#   34,
#   185,
#   186,
#   10,
#   21,
#   3,
#   187,
#   5,
#   39,
#   14,
#   188,
#   1],
#  [3,
#   83,
#   5,
#   84,
#   180,
#   7,
#   3,
#   181,
#   6,
#   182,
#   16,
#   183,
#   37,
#   184,
#   34,
#   185,
#   186,
#   10,
#   21,
#   3,
#   187,
#   5,
#   39,
#   14,
#   188,
#   1,
#   189],
#  [3,
#   83,
#   5,
#   84,
#   180,
#   7,
#   3,
#   181,
#   6,
#   182,
#   16,
#   183,
#   37,
#   184,
#   34,
#   185,
#   186,
#   10,
#   21,
#   3,
#   187,
#   5,
#   39,
#   14,
#   188,
#   1,
#   189,
#   85],
#  [3,
#   83,
#   5,
#   84,
#   180,
#   7,
#   3,
#   181,
#   6,
#   182,
#   16,
#   183,
#   37,
#   184,
#   34,
#   185,
#   186,
#   10,
#   21,
#   3,
#   187,
#   5,
#   39,
#   14,
#   188,
#   1,
#   189,
#   85,
#   12],
#  [3,
#   83,
#   5,
#   84,
#   180,
#   7,
#   3,
#   181,
#   6,
#   182,
#   16,
#   183,
#   37,
#   184,
#   34,
#   185,
#   186,
#   10,
#   21,
#   3,
#   187,
#   5,
#   39,
#   14,
#   188,
#   1,
#   189,
#   85,
#   12,
#   53],
#  [3,
#   83,
#   5,
#   84,
#   180,
#   7,
#   3,
#   181,
#   6,
#   182,
#   16,
#   183,
#   37,
#   184,
#   34,
#   185,
#   186,
#   10,
#   21,
#   3,
#   187,
#   5,
#   39,
#   14,
#   188,
#   1,
#   189,
#   85,
#   12,
#   53,
#   190],
#  [3,
#   83,
#   5,
#   84,
#   180,
#   7,
#   3,
#   181,
#   6,
#   182,
#   16,
#   183,
#   37,
#   184,
#   34,
#   185,
#   186,
#   10,
#   21,
#   3,
#   187,
#   5,
#   39,
#   14,
#   188,
#   1,
#   189,
#   85,
#   12,
#   53,
#   190,
#   7],
#  [3,
#   83,
#   5,
#   84,
#   180,
#   7,
#   3,
#   181,
#   6,
#   182,
#   16,
#   183,
#   37,
#   184,
#   34,
#   185,
#   186,
#   10,
#   21,
#   3,
#   187,
#   5,
#   39,
#   14,
#   188,
#   1,
#   189,
#   85,
#   12,
#   53,
#   190,
#   7,
#   191],
#  [3,
#   83,
#   5,
#   84,
#   180,
#   7,
#   3,
#   181,
#   6,
#   182,
#   16,
#   183,
#   37,
#   184,
#   34,
#   185,
#   186,
#   10,
#   21,
#   3,
#   187,
#   5,
#   39,
#   14,
#   188,
#   1,
#   189,
#   85,
#   12,
#   53,
#   190,
#   7,
#   191,
#   192],
#  [3,
#   83,
#   5,
#   84,
#   180,
#   7,
#   3,
#   181,
#   6,
#   182,
#   16,
#   183,
#   37,
#   184,
#   34,
#   185,
#   186,
#   10,
#   21,
#   3,
#   187,
#   5,
#   39,
#   14,
#   188,
#   1,
#   189,
#   85,
#   12,
#   53,
#   190,
#   7,
#   191,
#   192,
#   193],
#  [3,
#   83,
#   5,
#   84,
#   180,
#   7,
#   3,
#   181,
#   6,
#   182,
#   16,
#   183,
#   37,
#   184,
#   34,
#   185,
#   186,
#   10,
#   21,
#   3,
#   187,
#   5,
#   39,
#   14,
#   188,
#   1,
#   189,
#   85,
#   12,
#   53,
#   190,
#   7,
#   191,
#   192,
#   193,
#   6],
#  [3,
#   83,
#   5,
#   84,
#   180,
#   7,
#   3,
#   181,
#   6,
#   182,
#   16,
#   183,
#   37,
#   184,
#   34,
#   185,
#   186,
#   10,
#   21,
#   3,
#   187,
#   5,
#   39,
#   14,
#   188,
#   1,
#   189,
#   85,
#   12,
#   53,
#   190,
#   7,
#   191,
#   192,
#   193,
#   6,
#   4],
#  [3,
#   83,
#   5,
#   84,
#   180,
#   7,
#   3,
#   181,
#   6,
#   182,
#   16,
#   183,
#   37,
#   184,
#   34,
#   185,
#   186,
#   10,
#   21,
#   3,
#   187,
#   5,
#   39,
#   14,
#   188,
#   1,
#   189,
#   85,
#   12,
#   53,
#   190,
#   7,
#   191,
#   192,
#   193,
#   6,
#   4,
#   194],
#  [3,
#   83,
#   5,
#   84,
#   180,
#   7,
#   3,
#   181,
#   6,
#   182,
#   16,
#   183,
#   37,
#   184,
#   34,
#   185,
#   186,
#   10,
#   21,
#   3,
#   187,
#   5,
#   39,
#   14,
#   188,
#   1,
#   189,
#   85,
#   12,
#   53,
#   190,
#   7,
#   191,
#   192,
#   193,
#   6,
#   4,
#   194,
#   19],
#  [3,
#   83,
#   5,
#   84,
#   180,
#   7,
#   3,
#   181,
#   6,
#   182,
#   16,
#   183,
#   37,
#   184,
#   34,
#   185,
#   186,
#   10,
#   21,
#   3,
#   187,
#   5,
#   39,
#   14,
#   188,
#   1,
#   189,
#   85,
#   12,
#   53,
#   190,
#   7,
#   191,
#   192,
#   193,
#   6,
#   4,
#   194,
#   19,
#   195],
#  [3,
#   83,
#   5,
#   84,
#   180,
#   7,
#   3,
#   181,
#   6,
#   182,
#   16,
#   183,
#   37,
#   184,
#   34,
#   185,
#   186,
#   10,
#   21,
#   3,
#   187,
#   5,
#   39,
#   14,
#   188,
#   1,
#   189,
#   85,
#   12,
#   53,
#   190,
#   7,
#   191,
#   192,
#   193,
#   6,
#   4,
#   194,
#   19,
#   195,
#   196],
#  [3,
#   83,
#   5,
#   84,
#   180,
#   7,
#   3,
#   181,
#   6,
#   182,
#   16,
#   183,
#   37,
#   184,
#   34,
#   185,
#   186,
#   10,
#   21,
#   3,
#   187,
#   5,
#   39,
#   14,
#   188,
#   1,
#   189,
#   85,
#   12,
#   53,
#   190,
#   7,
#   191,
#   192,
#   193,
#   6,
#   4,
#   194,
#   19,
#   195,
#   196,
#   5],
#  [3,
#   83,
#   5,
#   84,
#   180,
#   7,
#   3,
#   181,
#   6,
#   182,
#   16,
#   183,
#   37,
#   184,
#   34,
#   185,
#   186,
#   10,
#   21,
#   3,
#   187,
#   5,
#   39,
#   14,
#   188,
#   1,
#   189,
#   85,
#   12,
#   53,
#   190,
#   7,
#   191,
#   192,
#   193,
#   6,
#   4,
#   194,
#   19,
#   195,
#   196,
#   5,
#   10],
#  [8, 1],
#  [8, 1, 86],
#  [8, 1, 86, 87],
#  [8, 1, 86, 87, 11],
#  [8, 1, 86, 87, 11, 9],
#  [8, 1, 86, 87, 11, 9, 2],
#  [86, 87],
#  [86, 87, 1],
#  [86, 87, 1, 3],
#  [86, 87, 1, 3, 88],
#  [86, 87, 1, 3, 88, 5],
#  [86, 87, 1, 3, 88, 5, 197],
#  [86, 87, 1, 3, 88, 5, 197, 198],
#  [86, 87, 1, 3, 88, 5, 197, 198, 14],
#  [86, 87, 1, 3, 88, 5, 197, 198, 14, 199],
#  [86, 87, 1, 3, 88, 5, 197, 198, 14, 199, 200],
#  [86, 87, 1, 3, 88, 5, 197, 198, 14, 199, 200, 39],
#  [86, 87, 1, 3, 88, 5, 197, 198, 14, 199, 200, 39, 46],
#  [86, 87, 1, 3, 88, 5, 197, 198, 14, 199, 200, 39, 46, 3],
#  [86, 87, 1, 3, 88, 5, 197, 198, 14, 199, 200, 39, 46, 3, 201],
#  [86, 87, 1, 3, 88, 5, 197, 198, 14, 199, 200, 39, 46, 3, 201, 10],
#  [86, 87, 1, 3, 88, 5, 197, 198, 14, 199, 200, 39, 46, 3, 201, 10, 7],
#  [86, 87, 1, 3, 88, 5, 197, 198, 14, 199, 200, 39, 46, 3, 201, 10, 7, 57],
#  [86, 87, 1, 3, 88, 5, 197, 198, 14, 199, 200, 39, 46, 3, 201, 10, 7, 57, 3],
#  [86,
#   87,
#   1,
#   3,
#   88,
#   5,
#   197,
#   198,
#   14,
#   199,
#   200,
#   39,
#   46,
#   3,
#   201,
#   10,
#   7,
#   57,
#   3,
#   52],
#  [86,
#   87,
#   1,
#   3,
#   88,
#   5,
#   197,
#   198,
#   14,
#   199,
#   200,
#   39,
#   46,
#   3,
#   201,
#   10,
#   7,
#   57,
#   3,
#   52,
#   5],
#  [86,
#   87,
#   1,
#   3,
#   88,
#   5,
#   197,
#   198,
#   14,
#   199,
#   200,
#   39,
#   46,
#   3,
#   201,
#   10,
#   7,
#   57,
#   3,
#   52,
#   5,
#   4],
#  [86,
#   87,
#   1,
#   3,
#   88,
#   5,
#   197,
#   198,
#   14,
#   199,
#   200,
#   39,
#   46,
#   3,
#   201,
#   10,
#   7,
#   57,
#   3,
#   52,
#   5,
#   4,
#   9],
#  [86,
#   87,
#   1,
#   3,
#   88,
#   5,
#   197,
#   198,
#   14,
#   199,
#   200,
#   39,
#   46,
#   3,
#   201,
#   10,
#   7,
#   57,
#   3,
#   52,
#   5,
#   4,
#   9,
#   2],
#  [86,
#   87,
#   1,
#   3,
#   88,
#   5,
#   197,
#   198,
#   14,
#   199,
#   200,
#   39,
#   46,
#   3,
#   201,
#   10,
#   7,
#   57,
#   3,
#   52,
#   5,
#   4,
#   9,
#   2,
#   18],
#  [8, 1],
#  [8, 1, 4],
#  [8, 1, 4, 15],
#  [8, 1, 4, 15, 25],
#  [4, 15],
#  [4, 15, 25],
#  [4, 15, 25, 1],
#  [4, 15, 25, 1, 4],
#  [4, 15, 25, 1, 4, 20],
#  [4, 15, 25, 1, 4, 20, 5],
#  [4, 15, 25, 1, 4, 20, 5, 9],
#  [4, 15, 25, 1, 4, 20, 5, 9, 2],
#  [4, 15, 25, 1, 4, 20, 5, 9, 2, 18],
#  [4, 15, 25, 1, 4, 20, 5, 9, 2, 18, 202],
#  [4, 15, 25, 1, 4, 20, 5, 9, 2, 18, 202, 33],
#  [4, 15, 25, 1, 4, 20, 5, 9, 2, 18, 202, 33, 3],
#  [4, 15, 25, 1, 4, 20, 5, 9, 2, 18, 202, 33, 3, 203],
#  [4, 15, 25, 1, 4, 20, 5, 9, 2, 18, 202, 33, 3, 203, 6],
#  [4, 15, 25, 1, 4, 20, 5, 9, 2, 18, 202, 33, 3, 203, 6, 204],
#  [4, 15, 25, 1, 4, 20, 5, 9, 2, 18, 202, 33, 3, 203, 6, 204, 5],
#  [4, 15, 25, 1, 4, 20, 5, 9, 2, 18, 202, 33, 3, 203, 6, 204, 5, 3],
#  [4, 15, 25, 1, 4, 20, 5, 9, 2, 18, 202, 33, 3, 203, 6, 204, 5, 3, 89],
#  [4, 15, 25, 1, 4, 20, 5, 9, 2, 18, 202, 33, 3, 203, 6, 204, 5, 3, 89, 205],
#  [4,
#   15,
#   25,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   18,
#   202,
#   33,
#   3,
#   203,
#   6,
#   204,
#   5,
#   3,
#   89,
#   205,
#   12],
#  [4,
#   15,
#   25,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   18,
#   202,
#   33,
#   3,
#   203,
#   6,
#   204,
#   5,
#   3,
#   89,
#   205,
#   12,
#   206],
#  [4,
#   15,
#   25,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   18,
#   202,
#   33,
#   3,
#   203,
#   6,
#   204,
#   5,
#   3,
#   89,
#   205,
#   12,
#   206,
#   5],
#  [4,
#   15,
#   25,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   18,
#   202,
#   33,
#   3,
#   203,
#   6,
#   204,
#   5,
#   3,
#   89,
#   205,
#   12,
#   206,
#   5,
#   207],
#  [4,
#   15,
#   25,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   18,
#   202,
#   33,
#   3,
#   203,
#   6,
#   204,
#   5,
#   3,
#   89,
#   205,
#   12,
#   206,
#   5,
#   207,
#   208],
#  [4,
#   15,
#   25,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   18,
#   202,
#   33,
#   3,
#   203,
#   6,
#   204,
#   5,
#   3,
#   89,
#   205,
#   12,
#   206,
#   5,
#   207,
#   208,
#   209],
#  [4,
#   15,
#   25,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   18,
#   202,
#   33,
#   3,
#   203,
#   6,
#   204,
#   5,
#   3,
#   89,
#   205,
#   12,
#   206,
#   5,
#   207,
#   208,
#   209,
#   210],
#  [4,
#   15,
#   25,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   18,
#   202,
#   33,
#   3,
#   203,
#   6,
#   204,
#   5,
#   3,
#   89,
#   205,
#   12,
#   206,
#   5,
#   207,
#   208,
#   209,
#   210,
#   11],
#  [4,
#   15,
#   25,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   18,
#   202,
#   33,
#   3,
#   203,
#   6,
#   204,
#   5,
#   3,
#   89,
#   205,
#   12,
#   206,
#   5,
#   207,
#   208,
#   209,
#   210,
#   11,
#   90],
#  [4,
#   15,
#   25,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   18,
#   202,
#   33,
#   3,
#   203,
#   6,
#   204,
#   5,
#   3,
#   89,
#   205,
#   12,
#   206,
#   5,
#   207,
#   208,
#   209,
#   210,
#   11,
#   90,
#   6],
#  [4,
#   15,
#   25,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   18,
#   202,
#   33,
#   3,
#   203,
#   6,
#   204,
#   5,
#   3,
#   89,
#   205,
#   12,
#   206,
#   5,
#   207,
#   208,
#   209,
#   210,
#   11,
#   90,
#   6,
#   211],
#  [4,
#   15,
#   25,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   18,
#   202,
#   33,
#   3,
#   203,
#   6,
#   204,
#   5,
#   3,
#   89,
#   205,
#   12,
#   206,
#   5,
#   207,
#   208,
#   209,
#   210,
#   11,
#   90,
#   6,
#   211,
#   22],
#  [4,
#   15,
#   25,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   18,
#   202,
#   33,
#   3,
#   203,
#   6,
#   204,
#   5,
#   3,
#   89,
#   205,
#   12,
#   206,
#   5,
#   207,
#   208,
#   209,
#   210,
#   11,
#   90,
#   6,
#   211,
#   22,
#   19],
#  [4,
#   15,
#   25,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   18,
#   202,
#   33,
#   3,
#   203,
#   6,
#   204,
#   5,
#   3,
#   89,
#   205,
#   12,
#   206,
#   5,
#   207,
#   208,
#   209,
#   210,
#   11,
#   90,
#   6,
#   211,
#   22,
#   19,
#   58],
#  [4,
#   15,
#   25,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   18,
#   202,
#   33,
#   3,
#   203,
#   6,
#   204,
#   5,
#   3,
#   89,
#   205,
#   12,
#   206,
#   5,
#   207,
#   208,
#   209,
#   210,
#   11,
#   90,
#   6,
#   211,
#   22,
#   19,
#   58,
#   24],
#  [4,
#   15,
#   25,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   18,
#   202,
#   33,
#   3,
#   203,
#   6,
#   204,
#   5,
#   3,
#   89,
#   205,
#   12,
#   206,
#   5,
#   207,
#   208,
#   209,
#   210,
#   11,
#   90,
#   6,
#   211,
#   22,
#   19,
#   58,
#   24,
#   36],
#  [4,
#   15,
#   25,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   18,
#   202,
#   33,
#   3,
#   203,
#   6,
#   204,
#   5,
#   3,
#   89,
#   205,
#   12,
#   206,
#   5,
#   207,
#   208,
#   209,
#   210,
#   11,
#   90,
#   6,
#   211,
#   22,
#   19,
#   58,
#   24,
#   36,
#   50],
#  [4,
#   15,
#   25,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   18,
#   202,
#   33,
#   3,
#   203,
#   6,
#   204,
#   5,
#   3,
#   89,
#   205,
#   12,
#   206,
#   5,
#   207,
#   208,
#   209,
#   210,
#   11,
#   90,
#   6,
#   211,
#   22,
#   19,
#   58,
#   24,
#   36,
#   50,
#   6],
#  [4,
#   15,
#   25,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   18,
#   202,
#   33,
#   3,
#   203,
#   6,
#   204,
#   5,
#   3,
#   89,
#   205,
#   12,
#   206,
#   5,
#   207,
#   208,
#   209,
#   210,
#   11,
#   90,
#   6,
#   211,
#   22,
#   19,
#   58,
#   24,
#   36,
#   50,
#   6,
#   212],
#  [4,
#   15,
#   25,
#   1,
#   4,
#   20,
#   5,
#   9,
#   2,
#   18,
#   202,
#   33,
#   3,
#   203,
#   6,
#   204,
#   5,
#   3,
#   89,
#   205,
#   12,
#   206,
#   5,
#   207,
#   208,
#   209,
#   210,
#   11,
#   90,
#   6,
#   211,
#   22,
#   19,
#   58,
#   24,
#   36,
#   50,
#   6,
#   212,
#   213],
#  [8, 1],
#  [8, 1, 4],
#  [8, 1, 4, 91],
#  [8, 1, 4, 91, 15],
#  [8, 1, 4, 91, 15, 25],
#  [8, 1, 4, 91, 15, 25, 92],
#  [4, 91],
#  [4, 91, 15],
#  [4, 91, 15, 25],
#  [4, 91, 15, 25, 92],
#  [4, 91, 15, 25, 92, 1],
#  [4, 91, 15, 25, 92, 1, 4],
#  [4, 91, 15, 25, 92, 1, 4, 93],
#  [4, 91, 15, 25, 92, 1, 4, 93, 20],
#  [4, 91, 15, 25, 92, 1, 4, 93, 20, 5],
#  [4, 91, 15, 25, 92, 1, 4, 93, 20, 5, 15],
#  [4, 91, 15, 25, 92, 1, 4, 93, 20, 5, 15, 25],
#  [4, 91, 15, 25, 92, 1, 4, 93, 20, 5, 15, 25, 214],
#  [4, 91, 15, 25, 92, 1, 4, 93, 20, 5, 15, 25, 214, 19],
#  [4, 91, 15, 25, 92, 1, 4, 93, 20, 5, 15, 25, 214, 19, 59],
#  [4, 91, 15, 25, 92, 1, 4, 93, 20, 5, 15, 25, 214, 19, 59, 215],
#  [4, 91, 15, 25, 92, 1, 4, 93, 20, 5, 15, 25, 214, 19, 59, 215, 24],
#  [4, 91, 15, 25, 92, 1, 4, 93, 20, 5, 15, 25, 214, 19, 59, 215, 24, 10],
#  [4, 91, 15, 25, 92, 1, 4, 93, 20, 5, 15, 25, 214, 19, 59, 215, 24, 10, 216],
#  [4,
#   91,
#   15,
#   25,
#   92,
#   1,
#   4,
#   93,
#   20,
#   5,
#   15,
#   25,
#   214,
#   19,
#   59,
#   215,
#   24,
#   10,
#   216,
#   217],
#  [4,
#   91,
#   15,
#   25,
#   92,
#   1,
#   4,
#   93,
#   20,
#   5,
#   15,
#   25,
#   214,
#   19,
#   59,
#   215,
#   24,
#   10,
#   216,
#   217,
#   218],
#  [4,
#   91,
#   15,
#   25,
#   92,
#   1,
#   4,
#   93,
#   20,
#   5,
#   15,
#   25,
#   214,
#   19,
#   59,
#   215,
#   24,
#   10,
#   216,
#   217,
#   218,
#   12],
#  [4,
#   91,
#   15,
#   25,
#   92,
#   1,
#   4,
#   93,
#   20,
#   5,
#   15,
#   25,
#   214,
#   19,
#   59,
#   215,
#   24,
#   10,
#   216,
#   217,
#   218,
#   12,
#   219],
#  [4,
#   91,
#   15,
#   25,
#   92,
#   1,
#   4,
#   93,
#   20,
#   5,
#   15,
#   25,
#   214,
#   19,
#   59,
#   215,
#   24,
#   10,
#   216,
#   217,
#   218,
#   12,
#   219,
#   90],
#  [4,
#   91,
#   15,
#   25,
#   92,
#   1,
#   4,
#   93,
#   20,
#   5,
#   15,
#   25,
#   214,
#   19,
#   59,
#   215,
#   24,
#   10,
#   216,
#   217,
#   218,
#   12,
#   219,
#   90,
#   5],
#  [4,
#   91,
#   15,
#   25,
#   92,
#   1,
#   4,
#   93,
#   20,
#   5,
#   15,
#   25,
#   214,
#   19,
#   59,
#   215,
#   24,
#   10,
#   216,
#   217,
#   218,
#   12,
#   219,
#   90,
#   5,
#   220],
#  [4,
#   91,
#   15,
#   25,
#   92,
#   1,
#   4,
#   93,
#   20,
#   5,
#   15,
#   25,
#   214,
#   19,
#   59,
#   215,
#   24,
#   10,
#   216,
#   217,
#   218,
#   12,
#   219,
#   90,
#   5,
#   220,
#   221],
#  [4,
#   91,
#   15,
#   25,
#   92,
#   1,
#   4,
#   93,
#   20,
#   5,
#   15,
#   25,
#   214,
#   19,
#   59,
#   215,
#   24,
#   10,
#   216,
#   217,
#   218,
#   12,
#   219,
#   90,
#   5,
#   220,
#   221,
#   7],
#  [4,
#   91,
#   15,
#   25,
#   92,
#   1,
#   4,
#   93,
#   20,
#   5,
#   15,
#   25,
#   214,
#   19,
#   59,
#   215,
#   24,
#   10,
#   216,
#   217,
#   218,
#   12,
#   219,
#   90,
#   5,
#   220,
#   221,
#   7,
#   222],
#  [4,
#   91,
#   15,
#   25,
#   92,
#   1,
#   4,
#   93,
#   20,
#   5,
#   15,
#   25,
#   214,
#   19,
#   59,
#   215,
#   24,
#   10,
#   216,
#   217,
#   218,
#   12,
#   219,
#   90,
#   5,
#   220,
#   221,
#   7,
#   222,
#   6],
#  [4,
#   91,
#   15,
#   25,
#   92,
#   1,
#   4,
#   93,
#   20,
#   5,
#   15,
#   25,
#   214,
#   19,
#   59,
#   215,
#   24,
#   10,
#   216,
#   217,
#   218,
#   12,
#   219,
#   90,
#   5,
#   220,
#   221,
#   7,
#   222,
#   6,
#   223],
#  [4,
#   91,
#   15,
#   25,
#   92,
#   1,
#   4,
#   93,
#   20,
#   5,
#   15,
#   25,
#   214,
#   19,
#   59,
#   215,
#   24,
#   10,
#   216,
#   217,
#   218,
#   12,
#   219,
#   90,
#   5,
#   220,
#   221,
#   7,
#   222,
#   6,
#   223,
#   65],
#  [4,
#   91,
#   15,
#   25,
#   92,
#   1,
#   4,
#   93,
#   20,
#   5,
#   15,
#   25,
#   214,
#   19,
#   59,
#   215,
#   24,
#   10,
#   216,
#   217,
#   218,
#   12,
#   219,
#   90,
#   5,
#   220,
#   221,
#   7,
#   222,
#   6,
#   223,
#   65,
#   39],
#  [4,
#   91,
#   15,
#   25,
#   92,
#   1,
#   4,
#   93,
#   20,
#   5,
#   15,
#   25,
#   214,
#   19,
#   59,
#   215,
#   24,
#   10,
#   216,
#   217,
#   218,
#   12,
#   219,
#   90,
#   5,
#   220,
#   221,
#   7,
#   222,
#   6,
#   223,
#   65,
#   39,
#   46],
#  [4,
#   91,
#   15,
#   25,
#   92,
#   1,
#   4,
#   93,
#   20,
#   5,
#   15,
#   25,
#   214,
#   19,
#   59,
#   215,
#   24,
#   10,
#   216,
#   217,
#   218,
#   12,
#   219,
#   90,
#   5,
#   220,
#   221,
#   7,
#   222,
#   6,
#   223,
#   65,
#   39,
#   46,
#   3],
#  [4,
#   91,
#   15,
#   25,
#   92,
#   1,
#   4,
#   93,
#   20,
#   5,
#   15,
#   25,
#   214,
#   19,
#   59,
#   215,
#   24,
#   10,
#   216,
#   217,
#   218,
#   12,
#   219,
#   90,
#   5,
#   220,
#   221,
#   7,
#   222,
#   6,
#   223,
#   65,
#   39,
#   46,
#   3,
#   10],
#  [8, 1],
#  [8, 1, 3],
#  [8, 1, 3, 224],
#  [8, 1, 3, 224, 5],
#  [8, 1, 3, 224, 5, 94],
#  [8, 1, 3, 224, 5, 94, 95],
#  [8, 1, 3, 224, 5, 94, 95, 11],
#  [8, 1, 3, 224, 5, 94, 95, 11, 26],
#  [8, 1, 3, 224, 5, 94, 95, 11, 26, 2],
#  [94, 95],
#  [94, 95, 1],
#  [94, 95, 1, 4],
#  [94, 95, 1, 4, 96],
#  [94, 95, 1, 4, 96, 22],
#  [94, 95, 1, 4, 96, 22, 11],
#  [94, 95, 1, 4, 96, 22, 11, 26],
#  [94, 95, 1, 4, 96, 22, 11, 26, 2],
#  [94, 95, 1, 4, 96, 22, 11, 26, 2, 7],
#  [94, 95, 1, 4, 96, 22, 11, 26, 2, 7, 57],
#  [94, 95, 1, 4, 96, 22, 11, 26, 2, 7, 57, 3],
#  [94, 95, 1, 4, 96, 22, 11, 26, 2, 7, 57, 3, 23],
#  [94, 95, 1, 4, 96, 22, 11, 26, 2, 7, 57, 3, 23, 88],
#  [94, 95, 1, 4, 96, 22, 11, 26, 2, 7, 57, 3, 23, 88, 6],
#  [94, 95, 1, 4, 96, 22, 11, 26, 2, 7, 57, 3, 23, 88, 6, 225],
#  [94, 95, 1, 4, 96, 22, 11, 26, 2, 7, 57, 3, 23, 88, 6, 225, 5],
#  [94, 95, 1, 4, 96, 22, 11, 26, 2, 7, 57, 3, 23, 88, 6, 225, 5, 15],
#  [94, 95, 1, 4, 96, 22, 11, 26, 2, 7, 57, 3, 23, 88, 6, 225, 5, 15, 97],
#  [94, 95, 1, 4, 96, 22, 11, 26, 2, 7, 57, 3, 23, 88, 6, 225, 5, 15, 97, 12],
#  [94,
#   95,
#   1,
#   4,
#   96,
#   22,
#   11,
#   26,
#   2,
#   7,
#   57,
#   3,
#   23,
#   88,
#   6,
#   225,
#   5,
#   15,
#   97,
#   12,
#   226],
#  [94,
#   95,
#   1,
#   4,
#   96,
#   22,
#   11,
#   26,
#   2,
#   7,
#   57,
#   3,
#   23,
#   88,
#   6,
#   225,
#   5,
#   15,
#   97,
#   12,
#   226,
#   3],
#  [94,
#   95,
#   1,
#   4,
#   96,
#   22,
#   11,
#   26,
#   2,
#   7,
#   57,
#   3,
#   23,
#   88,
#   6,
#   225,
#   5,
#   15,
#   97,
#   12,
#   226,
#   3,
#   227],
#  [94,
#   95,
#   1,
#   4,
#   96,
#   22,
#   11,
#   26,
#   2,
#   7,
#   57,
#   3,
#   23,
#   88,
#   6,
#   225,
#   5,
#   15,
#   97,
#   12,
#   226,
#   3,
#   227,
#   7],
#  [94,
#   95,
#   1,
#   4,
#   96,
#   22,
#   11,
#   26,
#   2,
#   7,
#   57,
#   3,
#   23,
#   88,
#   6,
#   225,
#   5,
#   15,
#   97,
#   12,
#   226,
#   3,
#   227,
#   7,
#   4],
#  [94,
#   95,
#   1,
#   4,
#   96,
#   22,
#   11,
#   26,
#   2,
#   7,
#   57,
#   3,
#   23,
#   88,
#   6,
#   225,
#   5,
#   15,
#   97,
#   12,
#   226,
#   3,
#   227,
#   7,
#   4,
#   228],
#  [94,
#   95,
#   1,
#   4,
#   96,
#   22,
#   11,
#   26,
#   2,
#   7,
#   57,
#   3,
#   23,
#   88,
#   6,
#   225,
#   5,
#   15,
#   97,
#   12,
#   226,
#   3,
#   227,
#   7,
#   4,
#   228,
#   229],
#  [94,
#   95,
#   1,
#   4,
#   96,
#   22,
#   11,
#   26,
#   2,
#   7,
#   57,
#   3,
#   23,
#   88,
#   6,
#   225,
#   5,
#   15,
#   97,
#   12,
#   226,
#   3,
#   227,
#   7,
#   4,
#   228,
#   229,
#   7],
#  [94,
#   95,
#   1,
#   4,
#   96,
#   22,
#   11,
#   26,
#   2,
#   7,
#   57,
#   3,
#   23,
#   88,
#   6,
#   225,
#   5,
#   15,
#   97,
#   12,
#   226,
#   3,
#   227,
#   7,
#   4,
#   228,
#   229,
#   7,
#   230],
#  [94,
#   95,
#   1,
#   4,
#   96,
#   22,
#   11,
#   26,
#   2,
#   7,
#   57,
#   3,
#   23,
#   88,
#   6,
#   225,
#   5,
#   15,
#   97,
#   12,
#   226,
#   3,
#   227,
#   7,
#   4,
#   228,
#   229,
#   7,
#   230,
#   231],
#  [94,
#   95,
#   1,
#   4,
#   96,
#   22,
#   11,
#   26,
#   2,
#   7,
#   57,
#   3,
#   23,
#   88,
#   6,
#   225,
#   5,
#   15,
#   97,
#   12,
#   226,
#   3,
#   227,
#   7,
#   4,
#   228,
#   229,
#   7,
#   230,
#   231,
#   232],
#  [94,
#   95,
#   1,
#   4,
#   96,
#   22,
#   11,
#   26,
#   2,
#   7,
#   57,
#   3,
#   23,
#   88,
#   6,
#   225,
#   5,
#   15,
#   97,
#   12,
#   226,
#   3,
#   227,
#   7,
#   4,
#   228,
#   229,
#   7,
#   230,
#   231,
#   232,
#   233],
#  [94,
#   95,
#   1,
#   4,
#   96,
#   22,
#   11,
#   26,
#   2,
#   7,
#   57,
#   3,
#   23,
#   88,
#   6,
#   225,
#   5,
#   15,
#   97,
#   12,
#   226,
#   3,
#   227,
#   7,
#   4,
#   228,
#   229,
#   7,
#   230,
#   231,
#   232,
#   233,
#   6],
#  [94,
#   95,
#   1,
#   4,
#   96,
#   22,
#   11,
#   26,
#   2,
#   7,
#   57,
#   3,
#   23,
#   88,
#   6,
#   225,
#   5,
#   15,
#   97,
#   12,
#   226,
#   3,
#   227,
#   7,
#   4,
#   228,
#   229,
#   7,
#   230,
#   231,
#   232,
#   233,
#   6,
#   234],
#  [94,
#   95,
#   1,
#   4,
#   96,
#   22,
#   11,
#   26,
#   2,
#   7,
#   57,
#   3,
#   23,
#   88,
#   6,
#   225,
#   5,
#   15,
#   97,
#   12,
#   226,
#   3,
#   227,
#   7,
#   4,
#   228,
#   229,
#   7,
#   230,
#   231,
#   232,
#   233,
#   6,
#   234,
#   235],
#  [8, 1],
#  [8, 1, 98],
#  [8, 1, 98, 2],
#  [8, 1, 98, 2, 11],
#  [8, 1, 98, 2, 11, 9],
#  [8, 1, 98, 2, 11, 9, 2],
#  [98, 2],
#  [98, 2, 1],
#  [98, 2, 1, 4],
#  [98, 2, 1, 4, 96],
#  [98, 2, 1, 4, 96, 21],
#  [98, 2, 1, 4, 96, 21, 4],
#  [98, 2, 1, 4, 96, 21, 4, 236],
#  [98, 2, 1, 4, 96, 21, 4, 236, 44],
#  [98, 2, 1, 4, 96, 21, 4, 236, 44, 18],
#  [98, 2, 1, 4, 96, 21, 4, 236, 44, 18, 237],
#  [98, 2, 1, 4, 96, 21, 4, 236, 44, 18, 237, 44],
#  [98, 2, 1, 4, 96, 21, 4, 236, 44, 18, 237, 44, 13],
#  [98, 2, 1, 4, 96, 21, 4, 236, 44, 18, 237, 44, 13, 4],
#  [98, 2, 1, 4, 96, 21, 4, 236, 44, 18, 237, 44, 13, 4, 85],
#  [98, 2, 1, 4, 96, 21, 4, 236, 44, 18, 237, 44, 13, 4, 85, 45],
#  [98, 2, 1, 4, 96, 21, 4, 236, 44, 18, 237, 44, 13, 4, 85, 45, 19],
#  [98, 2, 1, 4, 96, 21, 4, 236, 44, 18, 237, 44, 13, 4, 85, 45, 19, 4],
#  [98, 2, 1, 4, 96, 21, 4, 236, 44, 18, 237, 44, 13, 4, 85, 45, 19, 4, 93],
#  [98, 2, 1, 4, 96, 21, 4, 236, 44, 18, 237, 44, 13, 4, 85, 45, 19, 4, 93, 99],
#  [98,
#   2,
#   1,
#   4,
#   96,
#   21,
#   4,
#   236,
#   44,
#   18,
#   237,
#   44,
#   13,
#   4,
#   85,
#   45,
#   19,
#   4,
#   93,
#   99,
#   1],
#  [98,
#   2,
#   1,
#   4,
#   96,
#   21,
#   4,
#   236,
#   44,
#   18,
#   237,
#   44,
#   13,
#   4,
#   85,
#   45,
#   19,
#   4,
#   93,
#   99,
#   1,
#   238],
#  [98,
#   2,
#   1,
#   4,
#   96,
#   21,
#   4,
#   236,
#   44,
#   18,
#   237,
#   44,
#   13,
#   4,
#   85,
#   45,
#   19,
#   4,
#   93,
#   99,
#   1,
#   238,
#   239],
#  [98,
#   2,
#   1,
#   4,
#   96,
#   21,
#   4,
#   236,
#   44,
#   18,
#   237,
#   44,
#   13,
#   4,
#   85,
#   45,
#   19,
#   4,
#   93,
#   99,
#   1,
#   238,
#   239,
#   14],
#  [98,
#   2,
#   1,
#   4,
#   96,
#   21,
#   4,
#   236,
#   44,
#   18,
#   237,
#   44,
#   13,
#   4,
#   85,
#   45,
#   19,
#   4,
#   93,
#   99,
#   1,
#   238,
#   239,
#   14,
#   240],
#  [98,
#   2,
#   1,
#   4,
#   96,
#   21,
#   4,
#   236,
#   44,
#   18,
#   237,
#   44,
#   13,
#   4,
#   85,
#   45,
#   19,
#   4,
#   93,
#   99,
#   1,
#   238,
#   239,
#   14,
#   240,
#   19],
#  [98,
#   2,
#   1,
#   4,
#   96,
#   21,
#   4,
#   236,
#   44,
#   18,
#   237,
#   44,
#   13,
#   4,
#   85,
#   45,
#   19,
#   4,
#   93,
#   99,
#   1,
#   238,
#   239,
#   14,
#   240,
#   19,
#   4],
#  [98,
#   2,
#   1,
#   4,
#   96,
#   21,
#   4,
#   236,
#   44,
#   18,
#   237,
#   44,
#   13,
#   4,
#   85,
#   45,
#   19,
#   4,
#   93,
#   99,
#   1,
#   238,
#   239,
#   14,
#   240,
#   19,
#   4,
#   241],
#  [98,
#   2,
#   1,
#   4,
#   96,
#   21,
#   4,
#   236,
#   44,
#   18,
#   237,
#   44,
#   13,
#   4,
#   85,
#   45,
#   19,
#   4,
#   93,
#   99,
#   1,
#   238,
#   239,
#   14,
#   240,
#   19,
#   4,
#   241,
#   242],
#  [98,
#   2,
#   1,
#   4,
#   96,
#   21,
#   4,
#   236,
#   44,
#   18,
#   237,
#   44,
#   13,
#   4,
#   85,
#   45,
#   19,
#   4,
#   93,
#   99,
#   1,
#   238,
#   239,
#   14,
#   240,
#   19,
#   4,
#   241,
#   242,
#   243],
#  [98,
#   2,
#   1,
#   4,
#   96,
#   21,
#   4,
#   236,
#   44,
#   18,
#   237,
#   44,
#   13,
#   4,
#   85,
#   45,
#   19,
#   4,
#   93,
#   99,
#   1,
#   238,
#   239,
#   14,
#   240,
#   19,
#   4,
#   241,
#   242,
#   243,
#   99],
#  [98,
#   2,
#   1,
#   4,
#   96,
#   21,
#   4,
#   236,
#   44,
#   18,
#   237,
#   44,
#   13,
#   4,
#   85,
#   45,
#   19,
#   4,
#   93,
#   99,
#   1,
#   238,
#   239,
#   14,
#   240,
#   19,
#   4,
#   241,
#   242,
#   243,
#   99,
#   34],
#  [98,
#   2,
#   1,
#   4,
#   96,
#   21,
#   4,
#   236,
#   44,
#   18,
#   237,
#   44,
#   13,
#   4,
#   85,
#   45,
#   19,
#   4,
#   93,
#   99,
#   1,
#   238,
#   239,
#   14,
#   240,
#   19,
#   4,
#   241,
#   242,
#   243,
#   99,
#   34,
#   4],
#  [98,
#   2,
#   1,
#   4,
#   96,
#   21,
#   4,
#   236,
#   44,
#   18,
#   237,
#   44,
#   13,
#   4,
#   85,
#   45,
#   19,
#   4,
#   93,
#   99,
#   1,
#   238,
#   239,
#   14,
#   240,
#   19,
#   4,
#   241,
#   242,
#   243,
#   99,
#   34,
#   4,
#   244],
#  [98,
#   2,
#   1,
#   4,
#   96,
#   21,
#   4,
#   236,
#   44,
#   18,
#   237,
#   44,
#   13,
#   4,
#   85,
#   45,
#   19,
#   4,
#   93,
#   99,
#   1,
#   238,
#   239,
#   14,
#   240,
#   19,
#   4,
#   241,
#   242,
#   243,
#   99,
#   34,
#   4,
#   244,
#   45],
#  [8, 1],
#  [8, 1, 32],
#  [8, 1, 32, 100],
#  [8, 1, 32, 100, 101],
#  [8, 1, 32, 100, 101, 11],
#  [8, 1, 32, 100, 101, 11, 9],
#  [8, 1, 32, 100, 101, 11, 9, 2],
#  [32, 100],
#  [32, 100, 101],
#  [32, 100, 101, 102],
#  [32, 100, 101, 102, 245],
#  [32, 100, 101, 102, 245, 9],
#  [32, 100, 101, 102, 245, 9, 2],
#  [32, 100, 101, 102, 245, 9, 2, 63],
#  [32, 100, 101, 102, 245, 9, 2, 63, 7],
#  [32, 100, 101, 102, 245, 9, 2, 63, 7, 57],
#  [32, 100, 101, 102, 245, 9, 2, 63, 7, 57, 246],
#  [32, 100, 101, 102, 245, 9, 2, 63, 7, 57, 246, 52],
#  [32, 100, 101, 102, 245, 9, 2, 63, 7, 57, 246, 52, 247],
#  [32, 100, 101, 102, 245, 9, 2, 63, 7, 57, 246, 52, 247, 54],
#  [32, 100, 101, 102, 245, 9, 2, 63, 7, 57, 246, 52, 247, 54, 248],
#  [32, 100, 101, 102, 245, 9, 2, 63, 7, 57, 246, 52, 247, 54, 248, 249],
#  [32, 100, 101, 102, 245, 9, 2, 63, 7, 57, 246, 52, 247, 54, 248, 249, 103],
#  [32,
#   100,
#   101,
#   102,
#   245,
#   9,
#   2,
#   63,
#   7,
#   57,
#   246,
#   52,
#   247,
#   54,
#   248,
#   249,
#   103,
#   104],
#  [32,
#   100,
#   101,
#   102,
#   245,
#   9,
#   2,
#   63,
#   7,
#   57,
#   246,
#   52,
#   247,
#   54,
#   248,
#   249,
#   103,
#   104,
#   73],
#  [32,
#   100,
#   101,
#   102,
#   245,
#   9,
#   2,
#   63,
#   7,
#   57,
#   246,
#   52,
#   247,
#   54,
#   248,
#   249,
#   103,
#   104,
#   73,
#   250],
#  [32,
#   100,
#   101,
#   102,
#   245,
#   9,
#   2,
#   63,
#   7,
#   57,
#   246,
#   52,
#   247,
#   54,
#   248,
#   249,
#   103,
#   104,
#   73,
#   250,
#   251],
#  [32,
#   100,
#   101,
#   102,
#   245,
#   9,
#   2,
#   63,
#   7,
#   57,
#   246,
#   52,
#   247,
#   54,
#   248,
#   249,
#   103,
#   104,
#   73,
#   250,
#   251,
#   103],
#  [32,
#   100,
#   101,
#   102,
#   245,
#   9,
#   2,
#   63,
#   7,
#   57,
#   246,
#   52,
#   247,
#   54,
#   248,
#   249,
#   103,
#   104,
#   73,
#   250,
#   251,
#   103,
#   104],
#  [32,
#   100,
#   101,
#   102,
#   245,
#   9,
#   2,
#   63,
#   7,
#   57,
#   246,
#   52,
#   247,
#   54,
#   248,
#   249,
#   103,
#   104,
#   73,
#   250,
#   251,
#   103,
#   104,
#   252],
#  [32,
#   100,
#   101,
#   102,
#   245,
#   9,
#   2,
#   63,
#   7,
#   57,
#   246,
#   52,
#   247,
#   54,
#   248,
#   249,
#   103,
#   104,
#   73,
#   250,
#   251,
#   103,
#   104,
#   252,
#   6],
#  [32,
#   100,
#   101,
#   102,
#   245,
#   9,
#   2,
#   63,
#   7,
#   57,
#   246,
#   52,
#   247,
#   54,
#   248,
#   249,
#   103,
#   104,
#   73,
#   250,
#   251,
#   103,
#   104,
#   252,
#   6,
#   253],
#  [8, 1],
#  [8, 1, 105],
#  [8, 1, 105, 40],
#  [8, 1, 105, 40, 59],
#  [8, 1, 105, 40, 59, 106],
#  [8, 1, 105, 40, 59, 106, 11],
#  [8, 1, 105, 40, 59, 106, 11, 9],
#  [8, 1, 105, 40, 59, 106, 11, 9, 2],
#  [105, 40],
#  [105, 40, 59],
#  [105, 40, 59, 106],
#  [105, 40, 59, 106, 1],
#  [105, 40, 59, 106, 1, 4],
#  [105, 40, 59, 106, 1, 4, 254],
#  [105, 40, 59, 106, 1, 4, 254, 5],
#  [105, 40, 59, 106, 1, 4, 254, 5, 9],
#  [105, 40, 59, 106, 1, 4, 254, 5, 9, 2],
#  [105, 40, 59, 106, 1, 4, 254, 5, 9, 2, 255],
#  [105, 40, 59, 106, 1, 4, 254, 5, 9, 2, 255, 13],
#  [105, 40, 59, 106, 1, 4, 254, 5, 9, 2, 255, 13, 3],
#  [105, 40, 59, 106, 1, 4, 254, 5, 9, 2, 255, 13, 3, 256],
#  [105, 40, 59, 106, 1, 4, 254, 5, 9, 2, 255, 13, 3, 256, 35],
#  [105, 40, 59, 106, 1, 4, 254, 5, 9, 2, 255, 13, 3, 256, 35, 64],
#  [105, 40, 59, 106, 1, 4, 254, 5, 9, 2, 255, 13, 3, 256, 35, 64, 6],
#  [105, 40, 59, 106, 1, 4, 254, 5, 9, 2, 255, 13, 3, 256, 35, 64, 6, 89],
#  [105, 40, 59, 106, 1, 4, 254, 5, 9, 2, 255, 13, 3, 256, 35, 64, 6, 89, 40],
#  [105,
#   40,
#   59,
#   106,
#   1,
#   4,
#   254,
#   5,
#   9,
#   2,
#   255,
#   13,
#   3,
#   256,
#   35,
#   64,
#   6,
#   89,
#   40,
#   12],
#  [105,
#   40,
#   59,
#   106,
#   1,
#   4,
#   254,
#   5,
#   9,
#   2,
#   255,
#   13,
#   3,
#   256,
#   35,
#   64,
#   6,
#   89,
#   40,
#   12,
#   107],
#  [105,
#   40,
#   59,
#   106,
#   1,
#   4,
#   254,
#   5,
#   9,
#   2,
#   255,
#   13,
#   3,
#   256,
#   35,
#   64,
#   6,
#   89,
#   40,
#   12,
#   107,
#   58],
#  [105,
#   40,
#   59,
#   106,
#   1,
#   4,
#   254,
#   5,
#   9,
#   2,
#   255,
#   13,
#   3,
#   256,
#   35,
#   64,
#   6,
#   89,
#   40,
#   12,
#   107,
#   58,
#   24],
#  [105,
#   40,
#   59,
#   106,
#   1,
#   4,
#   254,
#   5,
#   9,
#   2,
#   255,
#   13,
#   3,
#   256,
#   35,
#   64,
#   6,
#   89,
#   40,
#   12,
#   107,
#   58,
#   24,
#   40],
#  [105,
#   40,
#   59,
#   106,
#   1,
#   4,
#   254,
#   5,
#   9,
#   2,
#   255,
#   13,
#   3,
#   256,
#   35,
#   64,
#   6,
#   89,
#   40,
#   12,
#   107,
#   58,
#   24,
#   40,
#   257],
#  [105,
#   40,
#   59,
#   106,
#   1,
#   4,
#   254,
#   5,
#   9,
#   2,
#   255,
#   13,
#   3,
#   256,
#   35,
#   64,
#   6,
#   89,
#   40,
#   12,
#   107,
#   58,
#   24,
#   40,
#   257,
#   258],
#  [105,
#   40,
#   59,
#   106,
#   1,
#   4,
#   254,
#   5,
#   9,
#   2,
#   255,
#   13,
#   3,
#   256,
#   35,
#   64,
#   6,
#   89,
#   40,
#   12,
#   107,
#   58,
#   24,
#   40,
#   257,
#   258,
#   259],
#  [105,
#   40,
#   59,
#   106,
#   1,
#   4,
#   254,
#   5,
#   9,
#   2,
#   255,
#   13,
#   3,
#   256,
#   35,
#   64,
#   6,
#   89,
#   40,
#   12,
#   107,
#   58,
#   24,
#   40,
#   257,
#   258,
#   259,
#   6],
#  [105,
#   40,
#   59,
#   106,
#   1,
#   4,
#   254,
#   5,
#   9,
#   2,
#   255,
#   13,
#   3,
#   256,
#   35,
#   64,
#   6,
#   89,
#   40,
#   12,
#   107,
#   58,
#   24,
#   40,
#   257,
#   258,
#   259,
#   6,
#   260],
#  [105,
#   40,
#   59,
#   106,
#   1,
#   4,
#   254,
#   5,
#   9,
#   2,
#   255,
#   13,
#   3,
#   256,
#   35,
#   64,
#   6,
#   89,
#   40,
#   12,
#   107,
#   58,
#   24,
#   40,
#   257,
#   258,
#   259,
#   6,
#   260,
#   261],
#  [8, 1],
#  [8, 1, 3],
#  [8, 1, 3, 71],
#  [8, 1, 3, 71, 35],
#  [8, 1, 3, 71, 35, 60],
#  [8, 1, 3, 71, 35, 60, 6],
#  [8, 1, 3, 71, 35, 60, 6, 61],
#  [8, 1, 3, 71, 35, 60, 6, 61, 11],
#  [8, 1, 3, 71, 35, 60, 6, 61, 11, 36],
#  [60, 1],
#  [60, 1, 3],
#  [60, 1, 3, 108],
#  [60, 1, 3, 108, 5],
#  [60, 1, 3, 108, 5, 41],
#  [60, 1, 3, 108, 5, 41, 27],
#  [60, 1, 3, 108, 5, 41, 27, 7],
#  [60, 1, 3, 108, 5, 41, 27, 7, 3],
#  [60, 1, 3, 108, 5, 41, 27, 7, 3, 109],
#  [60, 1, 3, 108, 5, 41, 27, 7, 3, 109, 5],
#  [60, 1, 3, 108, 5, 41, 27, 7, 3, 109, 5, 41],
#  [60, 1, 3, 108, 5, 41, 27, 7, 3, 109, 5, 41, 27],
#  [60, 1, 3, 108, 5, 41, 27, 7, 3, 109, 5, 41, 27, 6],
#  [60, 1, 3, 108, 5, 41, 27, 7, 3, 109, 5, 41, 27, 6, 110],
#  [60, 1, 3, 108, 5, 41, 27, 7, 3, 109, 5, 41, 27, 6, 110, 27],
#  [60, 1, 3, 108, 5, 41, 27, 7, 3, 109, 5, 41, 27, 6, 110, 27, 51],
#  [60, 1, 3, 108, 5, 41, 27, 7, 3, 109, 5, 41, 27, 6, 110, 27, 51, 61],
#  [60, 1, 3, 108, 5, 41, 27, 7, 3, 109, 5, 41, 27, 6, 110, 27, 51, 61, 1],
#  [60, 1, 3, 108, 5, 41, 27, 7, 3, 109, 5, 41, 27, 6, 110, 27, 51, 61, 1, 3],
#  [60,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   27,
#   51,
#   61,
#   1,
#   3,
#   108],
#  [60,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   27,
#   51,
#   61,
#   1,
#   3,
#   108,
#   5],
#  [60,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   27,
#   51,
#   61,
#   1,
#   3,
#   108,
#   5,
#   41],
#  [60,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   27,
#   51,
#   61,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27],
#  [60,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   27,
#   51,
#   61,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7],
#  [60,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   27,
#   51,
#   61,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3],
#  [60,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   27,
#   51,
#   61,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109],
#  [60,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   27,
#   51,
#   61,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5],
#  [60,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   27,
#   51,
#   61,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41],
#  [60,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   27,
#   51,
#   61,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27],
#  [60,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   27,
#   51,
#   61,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6],
#  [60,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   27,
#   51,
#   61,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110],
#  [60,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   27,
#   51,
#   61,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   262],
#  [60,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   27,
#   51,
#   61,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   262,
#   60],
#  [60,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   27,
#   51,
#   61,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   262,
#   60,
#   263],
#  [60,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   27,
#   51,
#   61,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   262,
#   60,
#   263,
#   3],
#  [60,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   27,
#   51,
#   61,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   262,
#   60,
#   263,
#   3,
#   264],
#  [60,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   27,
#   51,
#   61,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   262,
#   60,
#   263,
#   3,
#   264,
#   5],
#  [60,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   27,
#   51,
#   61,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   262,
#   60,
#   263,
#   3,
#   264,
#   5,
#   111],
#  [60,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   27,
#   51,
#   61,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   262,
#   60,
#   263,
#   3,
#   264,
#   5,
#   111,
#   42],
#  [60,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   27,
#   51,
#   61,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   262,
#   60,
#   263,
#   3,
#   264,
#   5,
#   111,
#   42,
#   51],
#  [60,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   27,
#   51,
#   61,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   262,
#   60,
#   263,
#   3,
#   264,
#   5,
#   111,
#   42,
#   51,
#   61],
#  [60,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   27,
#   51,
#   61,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   262,
#   60,
#   263,
#   3,
#   264,
#   5,
#   111,
#   42,
#   51,
#   61,
#   62],
#  [60,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   27,
#   51,
#   61,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   262,
#   60,
#   263,
#   3,
#   264,
#   5,
#   111,
#   42,
#   51,
#   61,
#   62,
#   13],
#  [60,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   27,
#   51,
#   61,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   262,
#   60,
#   263,
#   3,
#   264,
#   5,
#   111,
#   42,
#   51,
#   61,
#   62,
#   13,
#   265],
#  [60,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   27,
#   51,
#   61,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   262,
#   60,
#   263,
#   3,
#   264,
#   5,
#   111,
#   42,
#   51,
#   61,
#   62,
#   13,
#   265,
#   266],
#  [60,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   27,
#   51,
#   61,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   262,
#   60,
#   263,
#   3,
#   264,
#   5,
#   111,
#   42,
#   51,
#   61,
#   62,
#   13,
#   265,
#   266,
#   111],
#  [60,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   27,
#   51,
#   61,
#   1,
#   3,
#   108,
#   5,
#   41,
#   27,
#   7,
#   3,
#   109,
#   5,
#   41,
#   27,
#   6,
#   110,
#   262,
#   60,
#   263,
#   3,
#   264,
#   5,
#   111,
#   42,
#   51,
#   61,
#   62,
#   13,
#   265,
#   266,
#   111,
#   267],
#  [8, 1],
#  [8, 1, 26],
#  [8, 1, 26, 17],
#  [8, 1, 26, 17, 2],
#  [26, 17],
#  [26, 17, 2],
#  [26, 17, 2, 102],
#  [26, 17, 2, 102, 26],
#  [26, 17, 2, 102, 26, 2],
#  [26, 17, 2, 102, 26, 2, 54],
#  [26, 17, 2, 102, 26, 2, 54, 34],
#  [26, 17, 2, 102, 26, 2, 54, 34, 17],
#  [26, 17, 2, 102, 26, 2, 54, 34, 17, 2],
#  [26, 17, 2, 102, 26, 2, 54, 34, 17, 2, 268],
#  [26, 17, 2, 102, 26, 2, 54, 34, 17, 2, 268, 12],
#  [26, 17, 2, 102, 26, 2, 54, 34, 17, 2, 268, 12, 107],
#  [26, 17, 2, 102, 26, 2, 54, 34, 17, 2, 268, 12, 107, 23],
#  [26, 17, 2, 102, 26, 2, 54, 34, 17, 2, 268, 12, 107, 23, 15],
#  [26, 17, 2, 102, 26, 2, 54, 34, 17, 2, 268, 12, 107, 23, 15, 97],
#  [26, 17, 2, 102, 26, 2, 54, 34, 17, 2, 268, 12, 107, 23, 15, 97, 7],
#  [26, 17, 2, 102, 26, 2, 54, 34, 17, 2, 268, 12, 107, 23, 15, 97, 7, 28],
#  [26, 17, 2, 102, 26, 2, 54, 34, 17, 2, 268, 12, 107, 23, 15, 97, 7, 28, 29],
#  [26,
#   17,
#   2,
#   102,
#   26,
#   2,
#   54,
#   34,
#   17,
#   2,
#   268,
#   12,
#   107,
#   23,
#   15,
#   97,
#   7,
#   28,
#   29,
#   48],
#  [26,
#   17,
#   2,
#   102,
#   26,
#   2,
#   54,
#   34,
#   17,
#   2,
#   268,
#   12,
#   107,
#   23,
#   15,
#   97,
#   7,
#   28,
#   29,
#   48,
#   13],
#  [26,
#   17,
#   2,
#   102,
#   26,
#   2,
#   54,
#   34,
#   17,
#   2,
#   268,
#   12,
#   107,
#   23,
#   15,
#   97,
#   7,
#   28,
#   29,
#   48,
#   13,
#   4],
#  [26,
#   17,
#   2,
#   102,
#   26,
#   2,
#   54,
#   34,
#   17,
#   2,
#   268,
#   12,
#   107,
#   23,
#   15,
#   97,
#   7,
#   28,
#   29,
#   48,
#   13,
#   4,
#   269],
#  [26,
#   17,
#   2,
#   102,
#   26,
#   2,
#   54,
#   34,
#   17,
#   2,
#   268,
#   12,
#   107,
#   23,
#   15,
#   97,
#   7,
#   28,
#   29,
#   48,
#   13,
#   4,
#   269,
#   270],
#  [26,
#   17,
#   2,
#   102,
#   26,
#   2,
#   54,
#   34,
#   17,
#   2,
#   268,
#   12,
#   107,
#   23,
#   15,
#   97,
#   7,
#   28,
#   29,
#   48,
#   13,
#   4,
#   269,
#   270,
#   271],
#  [26,
#   17,
#   2,
#   102,
#   26,
#   2,
#   54,
#   34,
#   17,
#   2,
#   268,
#   12,
#   107,
#   23,
#   15,
#   97,
#   7,
#   28,
#   29,
#   48,
#   13,
#   4,
#   269,
#   270,
#   271,
#   22],
#  [26,
#   17,
#   2,
#   102,
#   26,
#   2,
#   54,
#   34,
#   17,
#   2,
#   268,
#   12,
#   107,
#   23,
#   15,
#   97,
#   7,
#   28,
#   29,
#   48,
#   13,
#   4,
#   269,
#   270,
#   271,
#   22,
#   11],
#  [26,
#   17,
#   2,
#   102,
#   26,
#   2,
#   54,
#   34,
#   17,
#   2,
#   268,
#   12,
#   107,
#   23,
#   15,
#   97,
#   7,
#   28,
#   29,
#   48,
#   13,
#   4,
#   269,
#   270,
#   271,
#   22,
#   11,
#   272],
#  [26,
#   17,
#   2,
#   102,
#   26,
#   2,
#   54,
#   34,
#   17,
#   2,
#   268,
#   12,
#   107,
#   23,
#   15,
#   97,
#   7,
#   28,
#   29,
#   48,
#   13,
#   4,
#   269,
#   270,
#   271,
#   22,
#   11,
#   272,
#   58],
#  [26,
#   17,
#   2,
#   102,
#   26,
#   2,
#   54,
#   34,
#   17,
#   2,
#   268,
#   12,
#   107,
#   23,
#   15,
#   97,
#   7,
#   28,
#   29,
#   48,
#   13,
#   4,
#   269,
#   270,
#   271,
#   22,
#   11,
#   272,
#   58,
#   24],
#  [26,
#   17,
#   2,
#   102,
#   26,
#   2,
#   54,
#   34,
#   17,
#   2,
#   268,
#   12,
#   107,
#   23,
#   15,
#   97,
#   7,
#   28,
#   29,
#   48,
#   13,
#   4,
#   269,
#   270,
#   271,
#   22,
#   11,
#   272,
#   58,
#   24,
#   273],
#  [26,
#   17,
#   2,
#   102,
#   26,
#   2,
#   54,
#   34,
#   17,
#   2,
#   268,
#   12,
#   107,
#   23,
#   15,
#   97,
#   7,
#   28,
#   29,
#   48,
#   13,
#   4,
#   269,
#   270,
#   271,
#   22,
#   11,
#   272,
#   58,
#   24,
#   273,
#   274],
#  [26,
#   17,
#   2,
#   102,
#   26,
#   2,
#   54,
#   34,
#   17,
#   2,
#   268,
#   12,
#   107,
#   23,
#   15,
#   97,
#   7,
#   28,
#   29,
#   48,
#   13,
#   4,
#   269,
#   270,
#   271,
#   22,
#   11,
#   272,
#   58,
#   24,
#   273,
#   274,
#   275],
#  [26,
#   17,
#   2,
#   102,
#   26,
#   2,
#   54,
#   34,
#   17,
#   2,
#   268,
#   12,
#   107,
#   23,
#   15,
#   97,
#   7,
#   28,
#   29,
#   48,
#   13,
#   4,
#   269,
#   270,
#   271,
#   22,
#   11,
#   272,
#   58,
#   24,
#   273,
#   274,
#   275,
#   14],
#  [26,
#   17,
#   2,
#   102,
#   26,
#   2,
#   54,
#   34,
#   17,
#   2,
#   268,
#   12,
#   107,
#   23,
#   15,
#   97,
#   7,
#   28,
#   29,
#   48,
#   13,
#   4,
#   269,
#   270,
#   271,
#   22,
#   11,
#   272,
#   58,
#   24,
#   273,
#   274,
#   275,
#   14,
#   276],
#  [26,
#   17,
#   2,
#   102,
#   26,
#   2,
#   54,
#   34,
#   17,
#   2,
#   268,
#   12,
#   107,
#   23,
#   15,
#   97,
#   7,
#   28,
#   29,
#   48,
#   13,
#   4,
#   269,
#   270,
#   271,
#   22,
#   11,
#   272,
#   58,
#   24,
#   273,
#   274,
#   275,
#   14,
#   276,
#   277],
#  [26,
#   17,
#   2,
#   102,
#   26,
#   2,
#   54,
#   34,
#   17,
#   2,
#   268,
#   12,
#   107,
#   23,
#   15,
#   97,
#   7,
#   28,
#   29,
#   48,
#   13,
#   4,
#   269,
#   270,
#   271,
#   22,
#   11,
#   272,
#   58,
#   24,
#   273,
#   274,
#   275,
#   14,
#   276,
#   277,
#   278]]

# %%
max_len = max([len(x) for x in input_sequences])

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_input_sequences = pad_sequences(input_sequences, maxlen = max_len , padding = 'pre')

# %%
X = padded_input_sequences[:,:-1]

# %%
y = padded_input_sequences[:,-1]

# %%
 len(tokenizer.word_index)
# Out:
# 278

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y,num_classes=305)

# %%
y.shape
# Out:
# (727, 305)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM , Dense

# %%
model = Sequential()
model.add(Embedding(305,100,input_length=47))
model.add(LSTM(151))
model.add(Dense(305,activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy' , optimizer = 'adam' , metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 47, 100)           30500
#
#  lstm_3 (LSTM)               (None, 151)               152208
#
#  dense_3 (Dense)             (None, 305)               46360
#
# =================================================================
# Total params: 229068 (894.80 KB)
# Trainable params: 229068 (894.80 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(X,y,epochs= 100)
# Out:
# Epoch 1/100
# 23/23 [==============================] - 3s 52ms/step - loss: 5.4862 - accuracy: 0.0468
# Epoch 2/100
# 23/23 [==============================] - 1s 50ms/step - loss: 5.0470 - accuracy: 0.0495
# Epoch 3/100
# 23/23 [==============================] - 1s 49ms/step - loss: 4.9502 - accuracy: 0.0619
# Epoch 4/100
# 23/23 [==============================] - 1s 50ms/step - loss: 4.8605 - accuracy: 0.0674
# Epoch 5/100
# 23/23 [==============================] - 1s 52ms/step - loss: 4.7701 - accuracy: 0.0963
# Epoch 6/100
# 23/23 [==============================] - 2s 83ms/step - loss: 4.6593 - accuracy: 0.1183
# Epoch 7/100
# 23/23 [==============================] - 1s 49ms/step - loss: 4.5334 - accuracy: 0.1183
# Epoch 8/100
# 23/23 [==============================] - 1s 49ms/step - loss: 4.3957 - accuracy: 0.1348
# Epoch 9/100
# 23/23 [==============================] - 1s 48ms/step - loss: 4.2439 - accuracy: 0.1733
# Epoch 10/100
# 23/23 [==============================] - 1s 50ms/step - loss: 4.0961 - accuracy: 0.1967
# Epoch 11/100
# 23/23 [==============================] - 1s 50ms/step - loss: 3.9315 - accuracy: 0.2242
# Epoch 12/100
# 23/23 [==============================] - 1s 51ms/step - loss: 3.7891 - accuracy: 0.2421
# Epoch 13/100
# 23/23 [==============================] - 1s 49ms/step - loss: 3.6303 - accuracy: 0.2462
# Epoch 14/100
# 23/23 [==============================] - 1s 49ms/step - loss: 3.4743 - accuracy: 0.2655
# Epoch 15/100
# 23/23 [==============================] - 2s 68ms/step - loss: 3.3290 - accuracy: 0.2751
# Epoch 16/100
# 23/23 [==============================] - 2s 69ms/step - loss: 3.1926 - accuracy: 0.2930
# Epoch 17/100
# 23/23 [==============================] - 1s 51ms/step - loss: 3.0501 - accuracy: 0.3177
# Epoch 18/100
# 23/23 [==============================] - 1s 51ms/step - loss: 2.9090 - accuracy: 0.3411
# Epoch 19/100
# 23/23 [==============================] - 1s 49ms/step - loss: 2.7678 - accuracy: 0.3659
# Epoch 20/100
# 23/23 [==============================] - 1s 50ms/step - loss: 2.6384 - accuracy: 0.3948
# Epoch 21/100
# 23/23 [==============================] - 1s 50ms/step - loss: 2.5162 - accuracy: 0.4154
# Epoch 22/100
# 23/23 [==============================] - 1s 50ms/step - loss: 2.3842 - accuracy: 0.4553
# Epoch 23/100
# 23/23 [==============================] - 1s 50ms/step - loss: 2.2646 - accuracy: 0.5021
# Epoch 24/100
# 23/23 [==============================] - 1s 50ms/step - loss: 2.1384 - accuracy: 0.5433
# Epoch 25/100
# 23/23 [==============================] - 2s 88ms/step - loss: 2.0273 - accuracy: 0.5667
# Epoch 26/100
# 23/23 [==============================] - 1s 50ms/step - loss: 1.9132 - accuracy: 0.6204
# Epoch 27/100
# 23/23 [==============================] - 1s 51ms/step - loss: 1.8070 - accuracy: 0.6561
# Epoch 28/100
# 23/23 [==============================] - 1s 49ms/step - loss: 1.7054 - accuracy: 0.6768
# Epoch 29/100
# 23/23 [==============================] - 1s 50ms/step - loss: 1.6083 - accuracy: 0.7098
# Epoch 30/100
# 23/23 [==============================] - 1s 49ms/step - loss: 1.5015 - accuracy: 0.7483
# Epoch 31/100
# 23/23 [==============================] - 1s 50ms/step - loss: 1.4169 - accuracy: 0.7565
# Epoch 32/100
# 23/23 [==============================] - 1s 51ms/step - loss: 1.3317 - accuracy: 0.7827
# Epoch 33/100
# 23/23 [==============================] - 1s 50ms/step - loss: 1.2486 - accuracy: 0.8074
# Epoch 34/100
# 23/23 [==============================] - 1s 65ms/step - loss: 1.1596 - accuracy: 0.8322
# Epoch 35/100
# 23/23 [==============================] - 2s 73ms/step - loss: 1.0893 - accuracy: 0.8487
# Epoch 36/100
# 23/23 [==============================] - 1s 49ms/step - loss: 1.0179 - accuracy: 0.8652
# Epoch 37/100
# 23/23 [==============================] - 1s 50ms/step - loss: 0.9553 - accuracy: 0.8776
# Epoch 38/100
# 23/23 [==============================] - 1s 50ms/step - loss: 0.9032 - accuracy: 0.8982
# Epoch 39/100
# 23/23 [==============================] - 1s 50ms/step - loss: 0.8448 - accuracy: 0.8982
# Epoch 40/100
# 23/23 [==============================] - 1s 50ms/step - loss: 0.7960 - accuracy: 0.9065
# Epoch 41/100
# 23/23 [==============================] - 1s 50ms/step - loss: 0.7466 - accuracy: 0.9133
# Epoch 42/100
# 23/23 [==============================] - 1s 50ms/step - loss: 0.7046 - accuracy: 0.9175
# Epoch 43/100
# 23/23 [==============================] - 1s 52ms/step - loss: 0.6638 - accuracy: 0.9175
# Epoch 44/100
# 23/23 [==============================] - 2s 87ms/step - loss: 0.6325 - accuracy: 0.9285
# Epoch 45/100
# 23/23 [==============================] - 1s 50ms/step - loss: 0.5957 - accuracy: 0.9298
# Epoch 46/100
# 23/23 [==============================] - 1s 51ms/step - loss: 0.5649 - accuracy: 0.9243
# Epoch 47/100
# 23/23 [==============================] - 1s 50ms/step - loss: 0.5403 - accuracy: 0.9340
# Epoch 48/100
# 23/23 [==============================] - 1s 51ms/step - loss: 0.5128 - accuracy: 0.9367
# Epoch 49/100
# 23/23 [==============================] - 1s 51ms/step - loss: 0.4885 - accuracy: 0.9409
# Epoch 50/100
# 23/23 [==============================] - 1s 50ms/step - loss: 0.4662 - accuracy: 0.9409
# Epoch 51/100
# 23/23 [==============================] - 1s 51ms/step - loss: 0.4488 - accuracy: 0.9422
# Epoch 52/100
# 23/23 [==============================] - 1s 52ms/step - loss: 0.4272 - accuracy: 0.9436
# Epoch 53/100
# 23/23 [==============================] - 2s 69ms/step - loss: 0.4098 - accuracy: 0.9491
# Epoch 54/100
# 23/23 [==============================] - 2s 71ms/step - loss: 0.3924 - accuracy: 0.9505
# Epoch 55/100
# 23/23 [==============================] - 1s 51ms/step - loss: 0.3783 - accuracy: 0.9519
# Epoch 56/100
# 23/23 [==============================] - 1s 51ms/step - loss: 0.3634 - accuracy: 0.9560
# Epoch 57/100
# 23/23 [==============================] - 1s 51ms/step - loss: 0.3517 - accuracy: 0.9505
# Epoch 58/100
# 23/23 [==============================] - 1s 51ms/step - loss: 0.3391 - accuracy: 0.9532
# Epoch 59/100
# 23/23 [==============================] - 1s 51ms/step - loss: 0.3298 - accuracy: 0.9546
# Epoch 60/100
# 23/23 [==============================] - 1s 50ms/step - loss: 0.3159 - accuracy: 0.9546
# Epoch 61/100
# 23/23 [==============================] - 1s 50ms/step - loss: 0.3065 - accuracy: 0.9546
# Epoch 62/100
# 23/23 [==============================] - 1s 53ms/step - loss: 0.2987 - accuracy: 0.9532
# Epoch 63/100
# 23/23 [==============================] - 2s 83ms/step - loss: 0.2890 - accuracy: 0.9532
# Epoch 64/100
# 23/23 [==============================] - 1s 51ms/step - loss: 0.2808 - accuracy: 0.9532
# Epoch 65/100
# 23/23 [==============================] - 1s 52ms/step - loss: 0.2732 - accuracy: 0.9546
# Epoch 66/100
# 23/23 [==============================] - 1s 50ms/step - loss: 0.2650 - accuracy: 0.9560
# Epoch 67/100
# 23/23 [==============================] - 1s 50ms/step - loss: 0.2576 - accuracy: 0.9546
# Epoch 68/100
# 23/23 [==============================] - 1s 51ms/step - loss: 0.2530 - accuracy: 0.9532
# Epoch 69/100
# 23/23 [==============================] - 1s 50ms/step - loss: 0.2449 - accuracy: 0.9574
# Epoch 70/100
# 23/23 [==============================] - 1s 50ms/step - loss: 0.2422 - accuracy: 0.9532
# Epoch 71/100
# 23/23 [==============================] - 1s 51ms/step - loss: 0.2354 - accuracy: 0.9546
# Epoch 72/100
# 23/23 [==============================] - 2s 76ms/step - loss: 0.2301 - accuracy: 0.9560
# Epoch 73/100
# 23/23 [==============================] - 1s 59ms/step - loss: 0.2249 - accuracy: 0.9546
# Epoch 74/100
# 23/23 [==============================] - 1s 51ms/step - loss: 0.2206 - accuracy: 0.9560
# Epoch 75/100
# 23/23 [==============================] - 1s 50ms/step - loss: 0.2161 - accuracy: 0.9505
# Epoch 76/100
# 23/23 [==============================] - 1s 52ms/step - loss: 0.2106 - accuracy: 0.9601
# Epoch 77/100
# 23/23 [==============================] - 1s 50ms/step - loss: 0.2069 - accuracy: 0.9560
# Epoch 78/100
# 23/23 [==============================] - 1s 50ms/step - loss: 0.2031 - accuracy: 0.9560
# Epoch 79/100
# 23/23 [==============================] - 1s 53ms/step - loss: 0.1993 - accuracy: 0.9560
# Epoch 80/100
# 23/23 [==============================] - 1s 54ms/step - loss: 0.1963 - accuracy: 0.9560
# Epoch 81/100
# 23/23 [==============================] - 1s 60ms/step - loss: 0.1918 - accuracy: 0.9574
# Epoch 82/100
# 23/23 [==============================] - 2s 76ms/step - loss: 0.1903 - accuracy: 0.9574
# Epoch 83/100
# 23/23 [==============================] - 1s 51ms/step - loss: 0.1864 - accuracy: 0.9546
# Epoch 84/100
# 23/23 [==============================] - 1s 51ms/step - loss: 0.1861 - accuracy: 0.9587
# Epoch 85/100
# 23/23 [==============================] - 1s 53ms/step - loss: 0.1817 - accuracy: 0.9574
# Epoch 86/100
# 23/23 [==============================] - 1s 51ms/step - loss: 0.1769 - accuracy: 0.9587
# Epoch 87/100
# 23/23 [==============================] - 1s 51ms/step - loss: 0.1763 - accuracy: 0.9574
# Epoch 88/100
# 23/23 [==============================] - 1s 51ms/step - loss: 0.1718 - accuracy: 0.9629
# Epoch 89/100
# 23/23 [==============================] - 1s 50ms/step - loss: 0.1695 - accuracy: 0.9587
# Epoch 90/100
# 23/23 [==============================] - 1s 52ms/step - loss: 0.1667 - accuracy: 0.9587
# Epoch 91/100
# 23/23 [==============================] - 2s 89ms/step - loss: 0.1653 - accuracy: 0.9560
# Epoch 92/100
# 23/23 [==============================] - 1s 52ms/step - loss: 0.1646 - accuracy: 0.9601
# Epoch 93/100
# 23/23 [==============================] - 1s 52ms/step - loss: 0.1627 - accuracy: 0.9615
# Epoch 94/100
# 23/23 [==============================] - 1s 51ms/step - loss: 0.1592 - accuracy: 0.9587
# Epoch 95/100
# 23/23 [==============================] - 1s 52ms/step - loss: 0.1590 - accuracy: 0.9601
# Epoch 96/100
# 23/23 [==============================] - 1s 51ms/step - loss: 0.1584 - accuracy: 0.9587
# Epoch 97/100
# 23/23 [==============================] - 1s 51ms/step - loss: 0.1570 - accuracy: 0.9560
# Epoch 98/100
# 23/23 [==============================] - 1s 50ms/step - loss: 0.1550 - accuracy: 0.9574
# Epoch 99/100
# 23/23 [==============================] - 1s 51ms/step - loss: 0.1528 - accuracy: 0.9574
# Epoch 100/100
# 23/23 [==============================] - 2s 72ms/step - loss: 0.1505 - accuracy: 0.9601

# %%
X
# Out:
# array([[  0,   0,   0, ...,   0,   0,   8],
#        [  0,   0,   0, ...,   0,   8,   1],
#        [  0,   0,   0, ...,   8,   1,   9],
#        ...,
#        [  0,   0,   0, ..., 274, 275,  14],
#        [  0,   0,   0, ..., 275,  14, 276],
#        [  0,   0,   0, ...,  14, 276, 277]], dtype=int32)

# %%
text = "machine"

# %%
#tokenize
token_text = tokenizer.texts_to_sequence([text])[0]
#padding
padded_token_text = pad_sequences([token_text] , maxlen = 47 , padding = 'pre')
#predict
pos = np.argmax(model.predict(padded_token_text))

for word,index in tokenizer.word_index.items():
  if index == pos:
    print(word)
